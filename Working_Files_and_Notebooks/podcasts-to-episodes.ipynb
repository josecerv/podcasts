# %%
"""
Podcast RSS Feed Processor
A script to process podcast RSS feeds and store episode data in PostgreSQL database.
"""

import feedparser
import pandas as pd
import threading
import queue
from sqlalchemy import create_engine, Column, Integer, String, Text, DateTime, UniqueConstraint
from sqlalchemy.orm import declarative_base, sessionmaker
from sqlalchemy.dialects.postgresql import insert
import logging
import os
from datetime import datetime
import hashlib
from concurrent.futures import ThreadPoolExecutor
import time
from typing import List, Dict, Any
from contextlib import contextmanager

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('podcast_processing.log'),
        logging.StreamHandler()  # Added for console output
    ]
)
logger = logging.getLogger(__name__)

# Database Configuration
Base = declarative_base()

class Episode(Base):
    """SQLAlchemy model for podcast episodes."""
    __tablename__ = 'episodes'
    __table_args__ = (
        UniqueConstraint('podcast_id', 'episode_id', name='_podcast_episode_uc'),
    )
    
    id = Column(Integer, primary_key=True, autoincrement=True)
    podcast_id = Column(String, index=True)
    episode_id = Column(String)
    episode_title = Column(Text)
    episode_description = Column(Text)
    episode_published = Column(DateTime)
    episode_link = Column(String)
    episode_duration = Column(String)

class DatabaseManager:
    """Manages database connections and operations."""
    def __init__(self):
        self.engine = create_engine(
            f'postgresql+psycopg2://{os.getenv("DB_USER", "jcervantez")}:'
            f'{os.getenv("DB_PASSWORD", "Cervantez12")}@'
            f'{os.getenv("DB_HOST", "localhost")}:'
            f'{os.getenv("DB_PORT", "5432")}/'
            f'{os.getenv("DB_NAME", "podcast_episodes")}',
            pool_size=30,
            max_overflow=0,
            pool_pre_ping=True
        )
        self.Session = sessionmaker(bind=self.engine)

    def init_db(self):
        """Initialize database tables."""
        Base.metadata.create_all(self.engine)

    @contextmanager
    def session_scope(self):
        """Provide a transactional scope around a series of operations."""
        session = self.Session()
        try:
            yield session
            session.commit()
        except Exception as e:
            session.rollback()
            raise
        finally:
            session.close()

class PodcastProcessor:
    """Handles the processing of podcast feeds."""
    def __init__(self, db_manager: DatabaseManager):
        self.db_manager = db_manager
        self.batch_size = 100
        self.episode_queue = queue.Queue(maxsize=1000)
        self.should_stop = threading.Event()

    @staticmethod
    def generate_episode_id(podcast_id: str, entry: Dict[str, Any]) -> str:
        """Generate a unique hash for an episode."""
        components = [
            podcast_id,
            entry.get('title', '').strip(),
            entry.get('link', '').strip(),
            str(entry.get('published_parsed', '')),
            entry.get('description', '').strip()
        ]
        unique_str = ''.join(components).encode('utf-8', 'ignore')
        return hashlib.sha256(unique_str).hexdigest()

    def process_entry(self, entry: Dict[str, Any], podcast_id: str) -> Dict[str, Any]:
        """Process a single feed entry."""
        try:
            published_parsed = entry.get('published_parsed')
            published_date = datetime(*published_parsed[:6]) if published_parsed else None

            # Get description from various possible fields
            description = entry.get('description', '')
            if not description:
                description = entry.get('summary', '')
            if not description:
                description = entry.get('itunes_summary', '')

            return {
                'podcast_id': podcast_id,
                'episode_id': self.generate_episode_id(podcast_id, entry),
                'episode_title': entry.get('title', '').strip(),
                'episode_description': description.strip(),
                'episode_published': published_date,
                'episode_link': entry.get('link', '').strip(),
                'episode_duration': entry.get('itunes_duration', '').strip()
            }
        except Exception as e:
            logger.error(f"Error processing entry: {e}")
            return None

    def process_feed(self, rss_url: str, podcast_id: str) -> None:
        """Process a single podcast feed."""
        try:
            feed = feedparser.parse(rss_url)
            if not feed.entries:
                logger.info(f"No entries found for podcast {podcast_id}")
                return

            episodes_batch = []
            for entry in feed.entries:
                episode_data = self.process_entry(entry, podcast_id)
                if episode_data:
                    episodes_batch.append(episode_data)
                
                if len(episodes_batch) >= self.batch_size:
                    self.episode_queue.put(episodes_batch)
                    episodes_batch = []

            if episodes_batch:
                self.episode_queue.put(episodes_batch)

        except Exception as e:
            logger.error(f"Error processing feed {podcast_id}: {e}")

    def batch_insert_worker(self) -> None:
        """Worker to handle batch insertions to database."""
        while not self.should_stop.is_set():
            try:
                batch = self.episode_queue.get(timeout=5)
                if batch is None:
                    self.episode_queue.task_done()
                    break

                try:
                    with self.db_manager.session_scope() as session:
                        stmt = insert(Episode).values(batch)
                        stmt = stmt.on_conflict_do_nothing(
                            index_elements=['podcast_id', 'episode_id']
                        )
                        session.execute(stmt)
                finally:
                    self.episode_queue.task_done()

            except queue.Empty:
                continue
            except Exception as e:
                logger.error(f"Error in batch insert: {e}")
                if 'batch' in locals():
                    self.episode_queue.task_done()

def process_podcasts(csv_path: str = 'podcasts_sample.csv', max_workers: int = 20):
    """Main processing function."""
    start_time = time.time()
    logger.info("Starting podcast processing")

    try:
        # Initialize components
        db_manager = DatabaseManager()
        db_manager.init_db()
        processor = PodcastProcessor(db_manager)

        # Load podcast data
        podcasts_df = pd.read_csv(csv_path, low_memory=False)
        total_podcasts = len(podcasts_df)
        logger.info(f"Found {total_podcasts} podcasts to process")

        # Start batch insert workers
        num_insert_workers = 5
        insert_workers = []
        for _ in range(num_insert_workers):
            worker = threading.Thread(target=processor.batch_insert_worker)
            worker.daemon = True
            worker.start()
            insert_workers.append(worker)

        try:
            # Process feeds
            with ThreadPoolExecutor(max_workers=max_workers) as executor:
                futures = [
                    executor.submit(processor.process_feed, row.rss, row.podcast_id)
                    for row in podcasts_df.itertuples()
                ]
                
                # Monitor progress
                completed = 0
                for future in futures:
                    try:
                        future.result(timeout=300)  # 5-minute timeout per feed
                        completed += 1
                        if completed % 100 == 0:
                            logger.info(f"Processed {completed}/{total_podcasts} feeds")
                    except Exception as e:
                        logger.error(f"Feed processing failed: {e}")

            # Wait for all tasks to be processed
            processor.episode_queue.join()

        finally:
            # Signal workers to stop
            processor.should_stop.set()
            for _ in range(num_insert_workers):
                processor.episode_queue.put(None)
            
            # Wait for workers to finish
            for worker in insert_workers:
                worker.join(timeout=5)

    except Exception as e:
        logger.error(f"Critical error: {e}")
        raise
    finally:
        processing_time = time.time() - start_time
        logger.info(f"Processing completed in {processing_time:.2f} seconds")

def main():
    """Entry point for script execution."""
    try:
        process_podcasts(
            csv_path='podcasts_sample.csv',
            max_workers=20
        )
    except KeyboardInterrupt:
        logger.info("Processing interrupted by user")
    except Exception as e:
        logger.error(f"Processing failed: {e}")

if __name__ == "__main__":
    main()
# Out:
# 2025-01-29 08:21:07,780 - INFO - Starting podcast processing
# 2025-01-29 08:21:09,511 - INFO - Found 117527 podcasts to process
# 2025-01-29 08:21:12,625 - INFO - No entries found for podcast 98e74c75ebb745a2ac94190e177c0bef
# 2025-01-29 08:21:18,811 - INFO - No entries found for podcast 6129d67770c544c994893fcb6423a19f
# 2025-01-29 08:21:27,445 - INFO - No entries found for podcast c044d3053396405d820893646f6a0604
# 2025-01-29 08:21:31,726 - INFO - No entries found for podcast f1597fcde1f5409f8907084552697c00
# 2025-01-29 08:21:32,250 - INFO - No entries found for podcast 818dc4fd7d154f049abfefb65fb5d4e0
# 2025-01-29 08:21:38,675 - INFO - No entries found for podcast b4d3983f995b48c7a9bb7c0d72391eae
# 2025-01-29 08:21:39,234 - INFO - No entries found for podcast 188de3b7bbcf45d089d310c960f3f81d
# 2025-01-29 08:21:40,192 - INFO - No entries found for podcast 9cec42394af64604899261c4134d9e19
# 2025-01-29 08:21:41,247 - INFO - No entries found for podcast 4cf1100f7d8d48818c1ea79c97a40999
# 2025-01-29 08:21:44,336 - INFO - No entries found for podcast d53c545a815f4a69833591995160c091
# 2025-01-29 08:21:47,453 - INFO - No entries found for podcast 3b1c270bfad748f6b28aed61c88c763e
# 2025-01-29 08:21:52,068 - INFO - No entries found for podcast abb9f6e3a8054f0c9f54c77cb50ab443
# 2025-01-29 08:21:57,060 - INFO - No entries found for podcast aa396a84243047dd8b801477c5ef5694
# 2025-01-29 08:21:57,811 - INFO - No entries found for podcast a311a567e3a8411e9e9e18ceb38c29cc
# 2025-01-29 08:21:57,851 - INFO - No entries found for podcast 752154a47aa24927b8dfebffd64627af
# 2025-01-29 08:21:58,153 - INFO - Processed 100/117527 feeds
# 2025-01-29 08:22:01,173 - INFO - No entries found for podcast d37298a38be94f34b322c03ac6f9f813
# 2025-01-29 08:22:02,607 - INFO - No entries found for podcast 5cd52c6e3ff349eab222723c79ce6892
# 2025-01-29 08:22:03,509 - INFO - No entries found for podcast 9e9044ccc3b54a38b278cac51ce6a3c2
# 2025-01-29 08:22:09,248 - INFO - No entries found for podcast ff64565ceddd4dad876ec55e3b64b357
# 2025-01-29 08:22:12,369 - INFO - Processed 200/117527 feeds
# 2025-01-29 08:22:12,385 - INFO - Processed 300/117527 feeds
# 2025-01-29 08:22:15,689 - INFO - No entries found for podcast e448da17bcc1431190a9d149069bc457
# 2025-01-29 08:22:19,392 - INFO - No entries found for podcast 3ab5d94de47b40d8b72ad7a4f08686f2
# 2025-01-29 08:22:23,067 - INFO - No entries found for podcast ed6f1519f5c54570814d97e613b76e8b
# 2025-01-29 08:22:29,052 - INFO - No entries found for podcast ec6e49e7bec446f2ae92c105c5d05751
# 2025-01-29 08:22:29,785 - INFO - No entries found for podcast f884b57c86d94180958aa4a9d8c78abd
# 2025-01-29 08:22:35,205 - INFO - No entries found for podcast 5d5aeccd482a441e9fa700ee9d3158bd
# 2025-01-29 08:22:35,893 - INFO - No entries found for podcast 6ed386f111524742915e9a62def44e3f
# 2025-01-29 08:22:36,489 - INFO - Processed 400/117527 feeds
# 2025-01-29 08:22:36,619 - INFO - No entries found for podcast 7dd4993757d44054a7600470e916dcef
# 2025-01-29 08:22:50,832 - INFO - No entries found for podcast c9ce22b3fe51432cafca6f26696c6d78
# 2025-01-29 08:22:52,702 - INFO - No entries found for podcast 73c093801d3c45acb10999aff6b2885b
# 2025-01-29 08:22:58,707 - INFO - Processed 500/117527 feeds
# 2025-01-29 08:23:01,731 - INFO - No entries found for podcast 8d79d13e7fc64b57bbdd606a30db0563
# 2025-01-29 08:23:06,984 - INFO - No entries found for podcast 9956b53215794b13900a2859c7c1a245
# 2025-01-29 08:23:10,601 - INFO - Processed 600/117527 feeds
# 2025-01-29 08:23:29,385 - INFO - No entries found for podcast fb33c69145e34faebaf16fe8580d81c5
# 2025-01-29 08:23:36,564 - INFO - No entries found for podcast abc79b4f15a141478b0adb7884f556a9
# 2025-01-29 08:23:37,872 - INFO - No entries found for podcast 83bb77f777ae4a6484f64e2634c4677d
# 2025-01-29 08:23:43,682 - INFO - Processed 700/117527 feeds
# 2025-01-29 08:23:43,836 - INFO - Processed 800/117527 feeds
# 2025-01-29 08:23:45,060 - INFO - Processed 900/117527 feeds
# 2025-01-29 08:23:46,452 - INFO - No entries found for podcast 98033c2707c54b8c966cd6c508501e46
# 2025-01-29 08:24:13,498 - INFO - No entries found for podcast 6ed50ddb99774392b5f2655a5757a496
# 2025-01-29 08:24:19,425 - INFO - Processed 1000/117527 feeds
# 2025-01-29 08:24:19,467 - INFO - Processed 1100/117527 feeds
# 2025-01-29 08:24:23,961 - INFO - No entries found for podcast a5ccb1be93f84996be97d6c25278ba19
# 2025-01-29 08:24:25,906 - INFO - Processed 1200/117527 feeds
# 2025-01-29 08:24:58,695 - INFO - Processed 1300/117527 feeds
# 2025-01-29 08:24:58,716 - INFO - Processed 1400/117527 feeds
# 2025-01-29 08:25:00,589 - INFO - No entries found for podcast a285435eacc049c4a7dcca96ddbe7fc9
# 2025-01-29 08:25:08,859 - INFO - No entries found for podcast 59ec7c459c65496a870a5a445505b523
# 2025-01-29 08:25:11,378 - INFO - No entries found for podcast cc70caa967c34b09b1579f88ad5b1839
# 2025-01-29 08:25:13,583 - INFO - No entries found for podcast 17d2bc1fe95243e4962c28a7217ea1f9
# 2025-01-29 08:25:16,181 - INFO - No entries found for podcast e72d1f8f0c9a4ca39f66cf25e1245004
# 2025-01-29 08:25:26,857 - INFO - No entries found for podcast c347b64c558c422a85c02f269ef143f3
# 2025-01-29 08:25:29,254 - INFO - Processed 1500/117527 feeds
# 2025-01-29 08:25:29,272 - INFO - Processed 1600/117527 feeds
# 2025-01-29 08:25:31,732 - INFO - No entries found for podcast 71b23f8a9b6947d289a613866a32f6ba
# 2025-01-29 08:25:35,081 - INFO - No entries found for podcast 4e8d217592344e109aee1668772cc96a
# 2025-01-29 08:25:35,792 - INFO - No entries found for podcast c615e06957744edb85912cd993febcaa
# 2025-01-29 08:25:42,780 - INFO - Processed 1700/117527 feeds
# 2025-01-29 08:25:48,646 - INFO - Processed 1800/117527 feeds
# 2025-01-29 08:25:48,708 - INFO - Processed 1900/117527 feeds
# 2025-01-29 08:25:59,110 - INFO - No entries found for podcast d9eaa37f036f4272a5c4b00cba435a09
# 2025-01-29 08:25:59,733 - INFO - No entries found for podcast 909411349da142a1ae90b8fbb07e92ed
# 2025-01-29 08:26:07,848 - INFO - No entries found for podcast 7c02b454fa5b4aeaa180977a1a7c44c3
# 2025-01-29 08:26:09,039 - INFO - No entries found for podcast 6cd582b12caa4d7c9b31864a4bd0f8c6
# 2025-01-29 08:26:09,494 - INFO - No entries found for podcast 31196a6babc14f5a90144dea447a4fa3
# 2025-01-29 08:26:17,788 - INFO - Processed 2000/117527 feeds
# 2025-01-29 08:26:38,234 - INFO - No entries found for podcast aaf041457845423ba1ffdb195a56d3ab
# 2025-01-29 08:26:40,637 - INFO - No entries found for podcast dae35845d8c8404b89d0bf49525c870e
# 2025-01-29 08:26:41,414 - INFO - No entries found for podcast d05c7a9a76f04d7e8511746294c392a5
# 2025-01-29 08:26:42,764 - INFO - No entries found for podcast d275f215233144ff93ad4e1171903331
# 2025-01-29 08:27:02,765 - INFO - No entries found for podcast 612ba7caa54649049ebfd7bd6d63c3ce
# 2025-01-29 08:27:04,461 - INFO - No entries found for podcast 1bfff90f1c6b491b8007828e0f08e75b
# 2025-01-29 08:27:07,031 - INFO - No entries found for podcast 436f2cffefd740799d0a09236edb202b
# 2025-01-29 08:27:11,890 - INFO - No entries found for podcast 2bc25438ffa54eda903dd818bb5037ca
# 2025-01-29 08:27:13,000 - INFO - No entries found for podcast 9b478c51f06c49bab58fec0d7dcb020e
# 2025-01-29 08:27:14,994 - INFO - No entries found for podcast 72c941d26ec244b4a1377f04b5baf6bb
# 2025-01-29 08:27:31,075 - INFO - No entries found for podcast 0be423467c6a4e33894f28fa97312fb3
# 2025-01-29 08:27:34,365 - INFO - No entries found for podcast eec68795728d425795f6ada8bd4e44c8
# 2025-01-29 08:27:36,914 - INFO - Processed 2100/117527 feeds
# 2025-01-29 08:27:36,960 - INFO - Processed 2200/117527 feeds
# 2025-01-29 08:27:36,995 - INFO - Processed 2300/117527 feeds
# 2025-01-29 08:27:37,014 - INFO - No entries found for podcast 3cfc2977298645a19bf36afb321c5bc9
# 2025-01-29 08:27:37,188 - INFO - Processed 2400/117527 feeds
# 2025-01-29 08:27:37,208 - INFO - Processed 2500/117527 feeds
# 2025-01-29 08:27:39,145 - INFO - No entries found for podcast 6b31ac90e00f41a6892e2b8987ead234
# 2025-01-29 08:27:39,848 - INFO - No entries found for podcast a3ad525309ba49f692cf420088025403
# 2025-01-29 08:27:40,500 - INFO - No entries found for podcast 6b68b98fdecb4ece9b1a1552b1c4b7aa
# 2025-01-29 08:27:40,884 - INFO - No entries found for podcast e5b6f052acab4c1dab65ee7f503fedbb
# 2025-01-29 08:27:43,633 - INFO - No entries found for podcast 5abf302a9da34cc79ae4cd357f5c0dd5
# 2025-01-29 08:27:46,915 - INFO - No entries found for podcast 61752926e2af492d86ca8d2ffe432bef
# 2025-01-29 08:27:55,372 - INFO - No entries found for podcast 90ac7ee246634ac7afb4333de68c6381
# 2025-01-29 08:28:07,577 - INFO - No entries found for podcast dad1f7fcbe0749de8ae34664bfada438
# 2025-01-29 08:28:16,025 - INFO - Processed 2600/117527 feeds
# 2025-01-29 08:28:16,136 - INFO - Processed 2700/117527 feeds
# 2025-01-29 08:28:16,154 - INFO - Processed 2800/117527 feeds
# 2025-01-29 08:28:16,241 - INFO - Processed 2900/117527 feeds
# 2025-01-29 08:28:26,829 - INFO - Processed 3000/117527 feeds
# 2025-01-29 08:28:29,070 - INFO - No entries found for podcast 120263d662af4d28b007312ba02a9d11
# 2025-01-29 08:28:29,088 - INFO - No entries found for podcast dfa21eae61864b84930f7959f55f6817
# 2025-01-29 08:28:32,471 - INFO - No entries found for podcast 2fb5dcaa783f4c419f7512aac0285b0e
# 2025-01-29 08:28:32,619 - INFO - Processed 3100/117527 feeds
# 2025-01-29 08:28:37,098 - INFO - No entries found for podcast afa99d51eb094192b356ff447066d02e
# 2025-01-29 08:28:42,938 - INFO - No entries found for podcast 0296ec2af94b433c8eba655d43ebfd0f
# 2025-01-29 08:28:45,972 - INFO - No entries found for podcast 77b128eea54d4c2a82e64d1b9083329b
# 2025-01-29 08:28:49,377 - INFO - No entries found for podcast 0e4a834011574a69b320c99bf8517625
# 2025-01-29 08:28:51,140 - INFO - No entries found for podcast 171581e34fa843c5b6f444615ce16277
# 2025-01-29 08:28:51,470 - INFO - No entries found for podcast 92bc42cca33547eb90969f2657b9c7f6
# 2025-01-29 08:28:52,979 - INFO - No entries found for podcast a05a2448cc2e4aa19ee6057dd7936c36
# 2025-01-29 08:28:53,957 - INFO - No entries found for podcast af7304a365d34a5489df036f62aede19
# 2025-01-29 08:28:53,976 - INFO - No entries found for podcast eba04a29216749cdb2fbd6c11938b3a1
# 2025-01-29 08:28:56,841 - INFO - No entries found for podcast 8bccff5c7dac465081bd796dcb644e1a
# 2025-01-29 08:28:59,547 - INFO - No entries found for podcast b3aa972cd01f4fc2b49efa68997af588
# 2025-01-29 08:29:03,143 - INFO - No entries found for podcast ba211087617e41f7b9dc0d67ab0bfc2e
# 2025-01-29 08:29:06,248 - INFO - Processed 3200/117527 feeds
# 2025-01-29 08:29:09,526 - INFO - No entries found for podcast bea38d670ba142e1af6898ffdc14f227
# 2025-01-29 08:29:15,326 - INFO - Processed 3300/117527 feeds
# 2025-01-29 08:29:17,983 - INFO - No entries found for podcast 832e6b5b1a504c6c84b6fb99c752c6d5
# 2025-01-29 08:29:26,424 - INFO - No entries found for podcast a9c2e5a6635d45fc82e4b50bec25fe55
# 2025-01-29 08:29:28,429 - INFO - No entries found for podcast c4221f940c454dd18f5ce21bed787497
# 2025-01-29 08:29:32,644 - INFO - Processed 3400/117527 feeds
# 2025-01-29 08:29:42,834 - INFO - Processed 3500/117527 feeds
# 2025-01-29 08:29:44,796 - INFO - No entries found for podcast ef2780ac5831456bb3c653855ed7d530
# 2025-01-29 08:29:45,007 - INFO - No entries found for podcast a78a4663895149be96e46ca85dcef64f
# 2025-01-29 08:29:45,732 - INFO - No entries found for podcast b7776dd6665940a7abe2bf31eeb1fb89
# 2025-01-29 08:29:46,501 - INFO - No entries found for podcast 56e9549a4dbe4623b7351cd0fbc77c6a
# 2025-01-29 08:29:46,735 - INFO - No entries found for podcast 402ef087413a455bb98e6d84d33bf41d
# 2025-01-29 08:29:54,780 - INFO - No entries found for podcast eb57470f47f54f5aa6dbdff7192f101b
# 2025-01-29 08:29:59,506 - INFO - Processed 3600/117527 feeds
# 2025-01-29 08:30:03,601 - INFO - No entries found for podcast cd0cbb86e6bc4f8b80f39f4837b7f71b
# 2025-01-29 08:30:13,525 - INFO - Processed 3700/117527 feeds
# 2025-01-29 08:30:20,253 - ERROR - Error processing feed f04b9b32318840d6a67ef5ad96650c1a: Remote end closed connection without response
# 2025-01-29 08:30:21,679 - INFO - No entries found for podcast e35400d4f87f47d2b858d99701dda813
# 2025-01-29 08:30:26,123 - INFO - Processed 3800/117527 feeds
# 2025-01-29 08:30:38,967 - INFO - Processed 3900/117527 feeds
# 2025-01-29 08:30:38,988 - INFO - No entries found for podcast 75d315514ab940869ea8978d108e5105
# 2025-01-29 08:30:45,607 - INFO - No entries found for podcast 8bb756df084b43678833b66046aef989
# 2025-01-29 08:30:50,392 - INFO - No entries found for podcast 595366f8b3884470b76e2b5ea7ef52d3
# 2025-01-29 08:30:50,751 - INFO - Processed 4000/117527 feeds
# 2025-01-29 08:30:51,008 - INFO - No entries found for podcast 579cc211a77a43de89f0ecf7c42dabad
# 2025-01-29 08:30:55,443 - INFO - No entries found for podcast f7aad72f25d444ebbfb62aebee6f9c78
# 2025-01-29 08:30:58,898 - INFO - No entries found for podcast 21abc599f67c45798a1489646d29699c
# 2025-01-29 08:30:59,470 - INFO - No entries found for podcast 13d6ccd885a5442e89a252cc746ee6a4
# 2025-01-29 08:31:02,461 - INFO - No entries found for podcast 3c95628ce34f49e78db2abe41f34b694
# 2025-01-29 08:31:10,902 - INFO - No entries found for podcast d845bdf6ba4842fb8fc936af63cf7a21
# 2025-01-29 08:31:11,153 - INFO - Processed 4100/117527 feeds
# 2025-01-29 08:31:16,734 - INFO - No entries found for podcast 134563fd719f4fa18b69efcf74966e52
# 2025-01-29 08:31:18,761 - INFO - No entries found for podcast 254de2b8e3844b78be19b9d0f93fc3c6
# 2025-01-29 08:31:23,179 - INFO - Processed 4200/117527 feeds
# 2025-01-29 08:31:26,482 - INFO - No entries found for podcast ac4e078a81b047028862c35772970862
# 2025-01-29 08:31:29,487 - INFO - No entries found for podcast 993b88942ec242c39f232520db655ff5
# 2025-01-29 08:31:36,005 - INFO - No entries found for podcast 6775aefbee894c8dbda3892bb5a2bf45
# 2025-01-29 08:31:41,899 - INFO - Processed 4300/117527 feeds
# 2025-01-29 08:31:43,368 - INFO - No entries found for podcast 3126c26eaeac46d99f13d8fe4630baf4
# 2025-01-29 08:31:45,340 - INFO - Processed 4400/117527 feeds
# 2025-01-29 08:31:49,995 - INFO - No entries found for podcast be9c9501a8504177a436763d280c24f6
# 2025-01-29 08:32:00,658 - INFO - Processed 4500/117527 feeds
# 2025-01-29 08:32:18,159 - INFO - Processed 4600/117527 feeds
# 2025-01-29 08:32:18,216 - INFO - No entries found for podcast 5a738e8d96d74dc8b8df010fe1ef0e55
# 2025-01-29 08:32:23,505 - INFO - No entries found for podcast e96ef093adcb4c17b6b180c63bd2a5ba
# 2025-01-29 08:32:25,360 - INFO - Processed 4700/117527 feeds
# 2025-01-29 08:32:26,163 - INFO - No entries found for podcast 628025470c8e4d858ae620d5f87d7d17
# 2025-01-29 08:32:27,506 - INFO - No entries found for podcast 23b23eb685a8427994bc319d6283fafe
# 2025-01-29 08:32:36,060 - INFO - No entries found for podcast 37169765e9e64a448c2b06b837ae5985
# 2025-01-29 08:32:36,096 - INFO - Processed 4800/117527 feeds
# 2025-01-29 08:32:37,699 - INFO - No entries found for podcast 2cdf3ae82bac4dcb90098d3b7f597597
# 2025-01-29 08:32:46,841 - INFO - No entries found for podcast d7da86a179bc41d1ab37666084e7e19b
# 2025-01-29 08:32:48,792 - INFO - No entries found for podcast 27f651a81d244915810b5cb497203e7f
# 2025-01-29 08:32:53,132 - INFO - No entries found for podcast ae7ff03b43e342878442473dcb443d40
# 2025-01-29 08:32:53,154 - INFO - No entries found for podcast cfc8f0cd566a48a68d2d159324492640
# 2025-01-29 08:32:58,103 - INFO - No entries found for podcast a25cfb2167c0470880660522f7175be0
# 2025-01-29 08:33:08,879 - INFO - Processed 4900/117527 feeds
# 2025-01-29 08:33:09,789 - INFO - Processed 5000/117527 feeds
# 2025-01-29 08:33:17,546 - INFO - No entries found for podcast 5fe3c9effb284c15a1d8220eadbeb254
# 2025-01-29 08:33:24,256 - INFO - No entries found for podcast 147ccbc863144005a894dccc98394776
# 2025-01-29 08:33:28,364 - INFO - Processed 5100/117527 feeds
# 2025-01-29 08:33:31,002 - INFO - No entries found for podcast 638aac842f9343159e1eb5d29f908681
# 2025-01-29 08:33:31,492 - INFO - No entries found for podcast e6b74d096a044cf387762aa41f78c661
# 2025-01-29 08:33:31,622 - INFO - No entries found for podcast 943bfe5d64a845f7a2862c9d9741aa4c
# 2025-01-29 08:33:35,062 - INFO - No entries found for podcast 8fac3f5128444064962e3ee14642c277
# 2025-01-29 08:33:37,573 - INFO - No entries found for podcast eba356da19e74ad39ad926a702d19636
# 2025-01-29 08:33:37,773 - INFO - No entries found for podcast fdc50a7e2ced4af8852a82024bc369c0
# 2025-01-29 08:33:38,624 - INFO - No entries found for podcast 675555abc10141eb847b7c382a33c494
# 2025-01-29 08:33:42,283 - INFO - Processed 5200/117527 feeds
# 2025-01-29 08:33:42,299 - INFO - Processed 5300/117527 feeds
# 2025-01-29 08:33:42,636 - INFO - No entries found for podcast 13464237664349e4afc1b8e8ef6dc67d
# 2025-01-29 08:33:44,658 - INFO - No entries found for podcast 4ab1857396074bfaa62dbf209074597d
# 2025-01-29 08:33:46,257 - INFO - No entries found for podcast 9d519dbe1b374685969c53427595906a
# 2025-01-29 08:33:53,742 - INFO - No entries found for podcast 0c7a71501f9843fb892cff817bf8393a
# 2025-01-29 08:33:54,564 - INFO - No entries found for podcast b93611fa64314fa5a7dff73b2f7857c8
# 2025-01-29 08:33:57,764 - INFO - No entries found for podcast 1d18000f1b0b41608b665c28a0eaca3a
# 2025-01-29 08:33:58,716 - INFO - No entries found for podcast 0a39bfe1750747cbb222835e381b1c4b
# 2025-01-29 08:33:58,753 - INFO - No entries found for podcast 6567feb9946d4ed8b3b46a4d13eb34e4
# 2025-01-29 08:34:04,038 - INFO - No entries found for podcast 52c6bc3fbc914250b4ca3fd2ad528982
# 2025-01-29 08:34:04,546 - INFO - Processed 5400/117527 feeds
# 2025-01-29 08:34:09,127 - INFO - No entries found for podcast 0853d0b945024e84abf20354d2d9514f
# 2025-01-29 08:34:19,503 - INFO - Processed 5500/117527 feeds
# 2025-01-29 08:34:24,463 - INFO - Processed 5600/117527 feeds
# 2025-01-29 08:34:28,535 - INFO - No entries found for podcast a61574cb68304ab19f89014b6ff9fef4
# 2025-01-29 08:34:36,348 - INFO - No entries found for podcast ff867a94ab2741cb886325390525df77
# 2025-01-29 08:34:41,485 - INFO - No entries found for podcast e0bb65255d9e4c5ea63c7942e77dca08
# 2025-01-29 08:34:41,487 - INFO - Processed 5700/117527 feeds
# 2025-01-29 08:34:42,584 - INFO - No entries found for podcast 6a46f96a9cb74518aab144c2fbce3ae1
# 2025-01-29 08:34:43,994 - INFO - No entries found for podcast 007561d8821340d2bf832d34ebb2ef80
# 2025-01-29 08:34:48,526 - INFO - No entries found for podcast ab6be76dbf034a1492ffdd61c8de6687
# 2025-01-29 08:34:59,882 - INFO - No entries found for podcast 099a0ea63be4413da557943e589b8b9d
# 2025-01-29 08:35:06,031 - INFO - Processed 5800/117527 feeds
# 2025-01-29 08:35:06,050 - INFO - Processed 5900/117527 feeds
# 2025-01-29 08:35:06,082 - INFO - Processed 6000/117527 feeds
# 2025-01-29 08:35:09,448 - INFO - No entries found for podcast c8225338cc654aa792ffe1c7a82870a7
# 2025-01-29 08:35:12,087 - INFO - No entries found for podcast 5f8092a79ebc4f099389b6f25090b455
# 2025-01-29 08:35:16,711 - INFO - No entries found for podcast 7b705efeeb3c485f84af24741040b837
# 2025-01-29 08:35:38,058 - INFO - Processed 6100/117527 feeds
# 2025-01-29 08:35:44,440 - INFO - No entries found for podcast 4190fd62c65c488d8511c421cc4417a1
# 2025-01-29 08:35:45,293 - INFO - No entries found for podcast 63695393d174438cac67775bb5642181
# 2025-01-29 08:35:47,048 - INFO - No entries found for podcast 1a96a2e864324664b9acc62d5e6d9320
# 2025-01-29 08:35:47,878 - INFO - No entries found for podcast e02cab718a8d49e3a8a4410745529f55
# 2025-01-29 08:35:48,961 - INFO - Processed 6200/117527 feeds
# 2025-01-29 08:35:50,126 - INFO - No entries found for podcast 6b8c4e1b888c4c94a795c75b76707c3f
# 2025-01-29 08:35:50,484 - INFO - No entries found for podcast 7b53944ffdcc452083270ffc5ee14626
# 2025-01-29 08:35:55,515 - INFO - No entries found for podcast cf3097a50f6841a1abaf94689e42433e
# 2025-01-29 08:35:56,068 - INFO - No entries found for podcast 43313c3655394f65a80ddc987d2bda71
# 2025-01-29 08:36:01,089 - INFO - No entries found for podcast 5e1646bd93d743068300cea943990f45
# 2025-01-29 08:36:01,304 - INFO - Processed 6300/117527 feeds
# 2025-01-29 08:36:07,711 - INFO - No entries found for podcast 756db52571ac41ae88c2552a34e54a29
# 2025-01-29 08:36:10,355 - INFO - Processed 6400/117527 feeds
# 2025-01-29 08:36:18,606 - INFO - No entries found for podcast 9eee8faafdb743ce82916d7dc9f160db
# 2025-01-29 08:36:22,182 - INFO - No entries found for podcast 0ae11c9dc0d74b61a136ed7fc9963f54
# 2025-01-29 08:36:30,869 - INFO - No entries found for podcast bd848b38b89f4c9c9b4f0a3a827bcb95
# 2025-01-29 08:36:33,085 - INFO - No entries found for podcast 7b29c80b3c1243d59b89e1db89337790
# 2025-01-29 08:36:33,622 - INFO - Processed 6500/117527 feeds
# 2025-01-29 08:36:35,714 - INFO - No entries found for podcast 8f940074ce604a44b76868a837998b88
# 2025-01-29 08:36:38,034 - INFO - No entries found for podcast b493f563640e4380b1aa9abec705731a
# 2025-01-29 08:36:41,159 - INFO - No entries found for podcast 5471aa0742b54b62a30e4edbd7aecec7
# 2025-01-29 08:36:42,430 - INFO - No entries found for podcast cb3cf1bd47aa49f6957de18fff1f7acf
# 2025-01-29 08:36:42,719 - INFO - No entries found for podcast dd7dc75caa8648c69a3ba5e115c772ea
# 2025-01-29 08:36:44,325 - INFO - No entries found for podcast 154ae4c0a3ad493eb2ae23bc64961c7b
# 2025-01-29 08:36:49,979 - INFO - No entries found for podcast 80e37a0d18484effaf73cebd9d7e08dc
# 2025-01-29 08:36:58,244 - INFO - No entries found for podcast f5ea5ed1d36645d0a8fb46abb6eb3421
# 2025-01-29 08:37:03,609 - INFO - No entries found for podcast f78f6c4e30a445c2b7f985b01ef0af16
# 2025-01-29 08:37:44,002 - INFO - No entries found for podcast 11c6c194733a4eb7a5bba602f7723871
# 2025-01-29 08:37:50,276 - INFO - No entries found for podcast 13909e8c9b4e41a6bccf64ffbf3482da
# 2025-01-29 08:37:51,239 - INFO - No entries found for podcast ded8fa0c65c24d0aa3adc4c018c45434
# 2025-01-29 08:37:51,507 - INFO - No entries found for podcast b96cb1a647b444b4bcf90cce0c96a678
# 2025-01-29 08:37:52,060 - INFO - No entries found for podcast 8da5bb58d52542849f93c83f96911941
# 2025-01-29 08:37:56,214 - INFO - No entries found for podcast e69093a1601c4b9d831ad914bd402b3a
# 2025-01-29 08:38:03,036 - INFO - No entries found for podcast 2cdc0a0eb51c4e989d3279ff5fead2d9
# 2025-01-29 08:38:03,705 - INFO - No entries found for podcast 4e8348f19ca7475d8fa863c7248e925f
# 2025-01-29 08:38:28,323 - INFO - No entries found for podcast eab9a144d3464a168afb196f31fe2210
# 2025-01-29 08:38:28,665 - INFO - No entries found for podcast ca58cc06ddd44af295b9ffe264ff2ab2
# 2025-01-29 08:38:33,809 - INFO - No entries found for podcast 806b428f19f84f80a7a439064af225db
# 2025-01-29 08:38:39,105 - INFO - No entries found for podcast 9c027c41610c40388dff6e9686a403cc
# 2025-01-29 08:38:39,257 - ERROR - Error processing feed 571572268d554b56a026255829b44443: IncompleteRead(475157 bytes read)
# 2025-01-29 08:38:48,402 - INFO - No entries found for podcast c96cf275912846348feeab4fb75cce63
# 2025-01-29 08:38:49,206 - INFO - No entries found for podcast ccf3462159f444e98c550637a9f21226
# 2025-01-29 08:38:56,428 - INFO - No entries found for podcast 2d69aea59f674e85a60b09498db86574
# 2025-01-29 08:38:56,800 - INFO - No entries found for podcast c83dfaffe1184de8b8cb74ca0e022885
# 2025-01-29 08:39:11,275 - INFO - No entries found for podcast fef35ab77837416ea3ed1bbe3a340823
# 2025-01-29 08:39:17,718 - INFO - No entries found for podcast 9c12d942f8eb46c0b6cc703e0ef69080
# 2025-01-29 08:39:35,831 - INFO - No entries found for podcast 4954a8585e2d4763ad5f27201294aa6d
# 2025-01-29 08:39:48,533 - INFO - No entries found for podcast 1f3ce1cce782463db9d35d33791c90d1
# 2025-01-29 08:39:50,934 - INFO - No entries found for podcast 6a8a7c30ef314f30b4482490d225371e
# 2025-01-29 08:39:51,368 - INFO - No entries found for podcast 849be26ffb334d46ad23fbb2c471fbf1
# 2025-01-29 08:39:52,169 - INFO - No entries found for podcast 38192a6a57724ae08e67ae80d2a6a36d
# 2025-01-29 08:40:06,791 - INFO - No entries found for podcast b4556046d9374341b0bd1387f2651511
# 2025-01-29 08:40:14,152 - INFO - No entries found for podcast f1f7dba6e5d7414995903c0b87dd5508
# 2025-01-29 08:40:32,997 - INFO - No entries found for podcast b435c5cf6fcc4b4da9c9927310364d57
# 2025-01-29 08:40:39,627 - INFO - No entries found for podcast 3a7003a8e5984e20a0520df187b78f9c
# 2025-01-29 08:40:40,642 - INFO - No entries found for podcast 5379bbcb53464dd38845d90d7d85fc59
# 2025-01-29 08:40:46,455 - INFO - No entries found for podcast d8d5cd6080bb43db944ebe3b738efdec
# 2025-01-29 08:40:52,206 - INFO - No entries found for podcast 57f65ffb65194ab18e44a493db330eaa
# 2025-01-29 08:40:55,114 - INFO - No entries found for podcast 540af9ca643e43829537a495e9850c6d
# 2025-01-29 08:40:57,996 - INFO - No entries found for podcast 13450cac21ab459685d5fecd0f730cab
# 2025-01-29 08:41:01,272 - INFO - No entries found for podcast 7982979110fc4e4891f4c9949b7c6521
# 2025-01-29 08:41:02,977 - INFO - No entries found for podcast 40c0ccd6524340fc92bb6ed315b10423
# 2025-01-29 08:41:08,160 - INFO - No entries found for podcast 70674226896e46618560e81cacb1f9b7
# 2025-01-29 08:41:16,287 - INFO - No entries found for podcast 3757eb4517b740cb9ed76c8f9477195c
# 2025-01-29 08:41:20,089 - INFO - No entries found for podcast 9d114f3b5fae45548d0c99edcb4a5122
# 2025-01-29 08:41:22,800 - INFO - No entries found for podcast 686448e009094c01b9d35d0b7638953a
# 2025-01-29 08:41:35,100 - INFO - No entries found for podcast 2b744e5b31d14b0b8b71a04f8a19978a
# 2025-01-29 08:41:38,578 - INFO - No entries found for podcast 3e4f976b1f9146989427e9fbbbd4afc4
# 2025-01-29 08:41:42,477 - INFO - No entries found for podcast 38529541d43049cf85b662d582351d92
# 2025-01-29 08:41:43,513 - INFO - No entries found for podcast 4a27b84fdf224172a4445028a9adb01e
# 2025-01-29 08:41:56,939 - INFO - No entries found for podcast f145e34b69e048d3ac3e3fa7363709c1
# 2025-01-29 08:41:57,474 - INFO - No entries found for podcast e4a590866e45438498de8d9a0bba9d7a
# 2025-01-29 08:42:00,516 - ERROR - Feed processing failed:
# 2025-01-29 08:42:00,674 - INFO - Processed 6600/117527 feeds
# 2025-01-29 08:42:00,674 - INFO - Processed 6700/117527 feeds
# 2025-01-29 08:42:00,675 - INFO - Processed 6800/117527 feeds
# 2025-01-29 08:42:00,675 - INFO - Processed 6900/117527 feeds
# 2025-01-29 08:42:00,676 - INFO - Processed 7000/117527 feeds
# 2025-01-29 08:42:00,676 - INFO - Processed 7100/117527 feeds
# 2025-01-29 08:42:00,677 - INFO - Processed 7200/117527 feeds
# 2025-01-29 08:42:00,678 - INFO - Processed 7300/117527 feeds
# 2025-01-29 08:42:00,678 - INFO - Processed 7400/117527 feeds
# 2025-01-29 08:42:00,679 - INFO - Processed 7500/117527 feeds
# 2025-01-29 08:42:00,679 - INFO - Processed 7600/117527 feeds
# 2025-01-29 08:42:00,680 - INFO - Processed 7700/117527 feeds
# 2025-01-29 08:42:00,680 - INFO - Processed 7800/117527 feeds
# 2025-01-29 08:42:00,681 - INFO - Processed 7900/117527 feeds
# 2025-01-29 08:42:00,681 - INFO - Processed 8000/117527 feeds
# 2025-01-29 08:42:00,698 - INFO - Processed 8100/117527 feeds
# 2025-01-29 08:42:00,707 - INFO - Processed 8200/117527 feeds
# 2025-01-29 08:42:07,363 - INFO - Processed 8300/117527 feeds
# 2025-01-29 08:42:07,381 - INFO - Processed 8400/117527 feeds
# 2025-01-29 08:42:13,118 - INFO - No entries found for podcast b29ed9978c874341accdaf56e0f6978c
# 2025-01-29 08:42:13,348 - INFO - No entries found for podcast 3fa25802a41141cc846376edea3baed1
# 2025-01-29 08:42:32,703 - INFO - Processed 8500/117527 feeds
# 2025-01-29 08:42:32,775 - INFO - Processed 8600/117527 feeds
# 2025-01-29 08:42:46,500 - INFO - No entries found for podcast b274c694d855426bbc505c863eeadbd7
# 2025-01-29 08:42:47,080 - INFO - Processed 8700/117527 feeds
# 2025-01-29 08:43:04,963 - INFO - No entries found for podcast c888fdacd2a24eac87baeffc1e804ccf
# 2025-01-29 08:43:09,316 - INFO - Processed 8800/117527 feeds
# 2025-01-29 08:43:16,640 - INFO - No entries found for podcast ad31d33694a84145a35af991377087a0
# 2025-01-29 08:43:28,357 - INFO - No entries found for podcast 93151de6704343a9afc0a6d2af067e75
# 2025-01-29 08:43:42,352 - INFO - Processed 8900/117527 feeds
# 2025-01-29 08:43:42,368 - INFO - Processed 9000/117527 feeds
# 2025-01-29 08:43:50,265 - INFO - No entries found for podcast cbcafeaa1ff24d46b71e8ce2753e324b
# 2025-01-29 08:43:57,320 - INFO - Processed 9100/117527 feeds
# 2025-01-29 08:44:03,907 - INFO - No entries found for podcast 2cd9764e27b94cd1ace4955647a7379f
# 2025-01-29 08:44:04,876 - INFO - No entries found for podcast badfd1e96fa34fa8895ee20627b8d570
# 2025-01-29 08:44:05,005 - INFO - No entries found for podcast 5f21170a37e340e9af65d1f1adc396e0
# 2025-01-29 08:44:13,830 - INFO - No entries found for podcast a0094215e70a4db2b16eea2ade19520c
# 2025-01-29 08:44:13,831 - INFO - Processed 9200/117527 feeds
# 2025-01-29 08:44:21,745 - INFO - Processed 9300/117527 feeds
# 2025-01-29 08:44:34,262 - INFO - No entries found for podcast efe8af670897444e8a0518a83ced7197
# 2025-01-29 08:44:37,374 - INFO - No entries found for podcast 4124632b0c8d43d28e18f9f0a8e58599
# 2025-01-29 08:44:38,815 - INFO - No entries found for podcast e675f773309a4381af48b219dfdfa2a0
# 2025-01-29 08:44:46,997 - INFO - No entries found for podcast 7c1da947d8b74fba8e634b0fb6e47c69
# 2025-01-29 08:44:48,307 - INFO - No entries found for podcast 713f043ecbe84c96b49ce500200bee9f
# 2025-01-29 08:44:54,580 - INFO - Processed 9400/117527 feeds
# 2025-01-29 08:44:54,621 - INFO - Processed 9500/117527 feeds
# 2025-01-29 08:45:16,457 - INFO - No entries found for podcast 376c74285f174c00b4d692e8c3ab4c31
# 2025-01-29 08:45:19,931 - INFO - Processed 9600/117527 feeds
# 2025-01-29 08:45:21,034 - INFO - No entries found for podcast 6f739ecf837744afa844a77a02967514
# 2025-01-29 08:45:21,831 - INFO - No entries found for podcast d533021a6eaa40398992142a5a1af165
# 2025-01-29 08:45:32,877 - INFO - Processed 9700/117527 feeds
# 2025-01-29 08:45:33,240 - INFO - No entries found for podcast ed387579c7bd47eda5374262ef9de171
# 2025-01-29 08:45:35,345 - INFO - No entries found for podcast 82c6aacfa7b442fa88fcb061dec1f9df
# 2025-01-29 08:45:38,699 - INFO - No entries found for podcast 618368487b9f4278b896241e1e9219b2
# 2025-01-29 08:45:42,532 - INFO - No entries found for podcast ba6e5e566c884a79b1a492381a7bbbdd
# 2025-01-29 08:45:53,558 - INFO - Processed 9800/117527 feeds
# 2025-01-29 08:46:02,907 - INFO - No entries found for podcast 8485bff3631c43f5be39811902ff3a4f
# 2025-01-29 08:46:03,499 - INFO - No entries found for podcast ce7798fbeb6445c5bfbdb2c8ad914629
# 2025-01-29 08:46:04,803 - INFO - No entries found for podcast 03cc22868b044b73a9b756864394e770
# 2025-01-29 08:46:15,588 - INFO - Processed 9900/117527 feeds
# 2025-01-29 08:46:15,837 - INFO - No entries found for podcast dde34ba0063346c5a645f75e18fb8197
# 2025-01-29 08:46:16,242 - INFO - No entries found for podcast 85c1ad38bbf145e5b82442ad9a045b8a
# 2025-01-29 08:46:20,956 - INFO - Processed 10000/117527 feeds
# 2025-01-29 08:46:25,195 - INFO - No entries found for podcast 10a54624583f4ee79b84b9d8ca2fea8e
# 2025-01-29 08:46:31,747 - INFO - No entries found for podcast 93317ba5ee4247ff8af8cb89952708ff
# 2025-01-29 08:46:45,077 - INFO - No entries found for podcast 2b3a7703f105441eb3f62151f9663923
# 2025-01-29 08:46:45,115 - INFO - Processed 10100/117527 feeds
# 2025-01-29 08:46:45,149 - INFO - Processed 10200/117527 feeds
# 2025-01-29 08:46:50,694 - INFO - No entries found for podcast 6d94d2f3ce7247d1be1df0cd92027074
# 2025-01-29 08:47:02,078 - INFO - No entries found for podcast 392c351495c04a5e98bddf8eccbac0f9
# 2025-01-29 08:47:02,617 - INFO - No entries found for podcast ed71dafab0834fa79c6925a9aef81290
# 2025-01-29 08:47:07,214 - INFO - No entries found for podcast ff722a4fbc9147bf9413ec7513ca6420
# 2025-01-29 08:47:07,325 - INFO - No entries found for podcast defec584025e47fb8a0087443ae1a63d
# 2025-01-29 08:47:12,204 - INFO - Processed 10300/117527 feeds
# 2025-01-29 08:47:12,392 - INFO - No entries found for podcast 7adffd7032774e2b93454e4b527eab95
# 2025-01-29 08:47:17,479 - INFO - No entries found for podcast e6b6cb28784c4134893dc705b2543bf7
# 2025-01-29 08:47:25,343 - INFO - Processed 10400/117527 feeds
# 2025-01-29 08:47:28,037 - INFO - No entries found for podcast 3701fd3097d248d899c2686c52ab14ce
# 2025-01-29 08:47:29,164 - INFO - No entries found for podcast 151f071d2882470a9390e7b5c919a38c
# 2025-01-29 08:47:33,217 - INFO - No entries found for podcast ce45e3ccfc07480abd0b44fe58ab5348
# 2025-01-29 08:47:38,334 - INFO - No entries found for podcast 4898aa8b83b9421993f82ee12162faf8
# 2025-01-29 08:47:38,800 - INFO - No entries found for podcast 16afccb281a1466b89af23ad2cb66f1f
# 2025-01-29 08:47:42,721 - INFO - No entries found for podcast 9d380c580bb1424687dd314baa8f8e00
# 2025-01-29 08:47:42,810 - INFO - No entries found for podcast ced10372cf6d4e1dbbe2f3edf066f714
# 2025-01-29 08:47:48,583 - INFO - No entries found for podcast 5a4f456d5c0341e18dd1b2789a9efa15
# 2025-01-29 08:47:48,631 - INFO - Processed 10500/117527 feeds
# 2025-01-29 08:47:50,774 - INFO - No entries found for podcast cc24ccd127b24500ad15d54316ff7cb0
# 2025-01-29 08:48:01,099 - INFO - No entries found for podcast aa3d40c0f72048b08e18dba8d0a60d2a
# 2025-01-29 08:48:02,059 - INFO - Processed 10600/117527 feeds
# 2025-01-29 08:48:06,923 - INFO - No entries found for podcast 618d18a0f44048819c2610a488e6cf5d
# 2025-01-29 08:48:11,461 - INFO - No entries found for podcast 61db45426e4f4153a9b91f3bbde08e4d
# 2025-01-29 08:48:16,666 - INFO - Processed 10700/117527 feeds
# 2025-01-29 08:48:18,633 - INFO - No entries found for podcast 0791ed8090ed4b37a6454c24b1442e82
# 2025-01-29 08:48:20,024 - INFO - No entries found for podcast 396c4fd85f8b4aa3b07a5fe607c76bf5
# 2025-01-29 08:48:21,621 - INFO - No entries found for podcast 7c9b80eb6b6d452dbd7e48af503bb85d
# 2025-01-29 08:48:23,143 - INFO - No entries found for podcast d5d0aa78814b47d39883b7fb262c5ff1
# 2025-01-29 08:48:26,394 - INFO - Processed 10800/117527 feeds
# 2025-01-29 08:48:37,493 - INFO - No entries found for podcast 257ebada0e9240e6b1faadbc787527a5
# 2025-01-29 08:48:43,141 - INFO - Processed 10900/117527 feeds
# 2025-01-29 08:48:44,873 - INFO - No entries found for podcast c135cf15541e45b3b0a227d6194e4657
# 2025-01-29 08:48:50,626 - INFO - Processed 11000/117527 feeds
# 2025-01-29 08:48:56,271 - INFO - No entries found for podcast 69aa1ad0bc184d718ef6e64198527bf8
# 2025-01-29 08:48:57,137 - INFO - No entries found for podcast 533bdd3a6bd348579bc1301a048c6b45
# 2025-01-29 08:48:57,930 - INFO - No entries found for podcast d6a3a04c7d3a4ca2abe221f817308ae1
# 2025-01-29 08:48:57,973 - INFO - No entries found for podcast 72cadc8ad6794cc8a0471e9e75db5f03
# 2025-01-29 08:48:59,394 - INFO - No entries found for podcast 35cfce4daffc4beab3fa55320292dc87
# 2025-01-29 08:48:59,607 - INFO - No entries found for podcast 3bfb846d9f8944668fae29a59ba9a998
# 2025-01-29 08:49:01,424 - INFO - No entries found for podcast 19926293b7e547ff80e9f5e3ec7e30da
# 2025-01-29 08:49:04,154 - INFO - No entries found for podcast 471456c828b7477aa9b694c0bc248a11
# 2025-01-29 08:49:04,345 - INFO - No entries found for podcast 28b9b24721ab4b11a6ff218ba3355c57
# 2025-01-29 08:49:05,369 - INFO - No entries found for podcast a21debb1bfc34773b32193679b0e169a
# 2025-01-29 08:49:05,452 - INFO - Processed 11100/117527 feeds
# 2025-01-29 08:49:05,499 - INFO - Processed 11200/117527 feeds
# 2025-01-29 08:49:34,053 - INFO - No entries found for podcast 3a17c63d961649609603068bc5f65398
# 2025-01-29 08:49:52,277 - INFO - No entries found for podcast 849a56213100457383d688b41bd0950d
# 2025-01-29 08:49:52,858 - INFO - No entries found for podcast d93ddbcbac5d47e4ae8504dbddc261c3
# 2025-01-29 08:49:55,899 - INFO - No entries found for podcast eb9bb16c90be4e1498fa01ea46c06669
# 2025-01-29 08:49:58,419 - INFO - Processed 11300/117527 feeds
# 2025-01-29 08:49:58,507 - INFO - Processed 11400/117527 feeds
# 2025-01-29 08:49:58,788 - INFO - No entries found for podcast 1136ad21766544d6ba13b297b170ba9a
# 2025-01-29 08:50:12,848 - INFO - Processed 11500/117527 feeds
# 2025-01-29 08:50:15,728 - INFO - No entries found for podcast d12604a6bdb64a40b2b3b111b15155e0
# 2025-01-29 08:50:19,573 - INFO - No entries found for podcast 1ba67c036e7944f0ab42158a6bbe5b14
# 2025-01-29 08:50:22,921 - INFO - Processed 11600/117527 feeds
# 2025-01-29 08:50:32,958 - INFO - Processed 11700/117527 feeds
# 2025-01-29 08:50:42,459 - INFO - No entries found for podcast e125622a0f6d4d5195e53b9f2206a116
# 2025-01-29 08:50:44,931 - INFO - Processed 11800/117527 feeds
# 2025-01-29 08:50:45,364 - INFO - No entries found for podcast 549c06f67a474f73a4f3e36e6050e736
# 2025-01-29 08:50:56,895 - INFO - No entries found for podcast b7b5cb6ea26247cf885ea2651179cd74
# 2025-01-29 08:50:58,176 - INFO - No entries found for podcast 60b97c9b8851459286546ed86b7f3090
# 2025-01-29 08:51:08,052 - INFO - Processed 11900/117527 feeds
# 2025-01-29 08:51:08,908 - INFO - No entries found for podcast 654cec3f19714cc0b3f73ed5dd84939a
# 2025-01-29 08:51:12,829 - INFO - No entries found for podcast b4c144f6832048e78d5ac84c9d131c3e
# 2025-01-29 08:51:13,292 - INFO - Processed 12000/117527 feeds
# 2025-01-29 08:51:16,074 - INFO - No entries found for podcast cc8975eb1ad24fd88d99d6796370763f
# 2025-01-29 08:51:19,516 - INFO - No entries found for podcast 51ff5d5a230147839b26688e7a3ee49f
# 2025-01-29 08:51:28,617 - INFO - No entries found for podcast 75c12e90f9ed494f8caefa9b2d4addc0
# 2025-01-29 08:51:29,392 - INFO - No entries found for podcast 7e9900fef73649c393ff345188ab156c
# 2025-01-29 08:51:32,137 - INFO - No entries found for podcast 849af8adb6d94af09c8098abe3e6d8fa
# 2025-01-29 08:51:36,720 - INFO - Processed 12100/117527 feeds
# 2025-01-29 08:51:38,040 - INFO - No entries found for podcast 034c60fa12bc42a286e9b8dbef2352ba
# 2025-01-29 08:51:41,497 - INFO - No entries found for podcast c874f41b03164add933901754b3c7074
# 2025-01-29 08:51:44,178 - INFO - No entries found for podcast 7a5d5c53e54c417f92f72e9c568c2d43
# 2025-01-29 08:51:45,431 - INFO - No entries found for podcast 2a1a197a06814339b17ea9de734d946a
# 2025-01-29 08:51:46,324 - INFO - Processed 12200/117527 feeds
# 2025-01-29 08:51:46,344 - INFO - Processed 12300/117527 feeds
# 2025-01-29 08:52:02,357 - INFO - No entries found for podcast dfc8c8f37dfa4da5bfc68960e686113f
# 2025-01-29 08:52:02,527 - INFO - No entries found for podcast b6c249f2b8aa42b48333afd800242aa5
# 2025-01-29 08:52:07,860 - INFO - Processed 12400/117527 feeds
# 2025-01-29 08:52:13,334 - INFO - No entries found for podcast 91c962f6636c4aa1a6a3e0ab659ea7b8
# 2025-01-29 08:52:14,672 - INFO - Processed 12500/117527 feeds
# 2025-01-29 08:52:15,481 - INFO - No entries found for podcast 7d9d315049eb49948590adbaf1054ba8
# 2025-01-29 08:52:21,293 - INFO - No entries found for podcast 03cbd7eed1cf4687913b3690f8f5e709
# 2025-01-29 08:52:24,136 - INFO - No entries found for podcast b48b5a84266c4740be84c7cc17660696
# 2025-01-29 08:52:24,221 - INFO - Processed 12600/117527 feeds
# 2025-01-29 08:52:50,371 - INFO - No entries found for podcast f060aa417d1b46afbf5377c9c2b0e7b1
# 2025-01-29 08:52:55,271 - INFO - Processed 12700/117527 feeds
# 2025-01-29 08:52:55,288 - INFO - Processed 12800/117527 feeds
# 2025-01-29 08:52:59,942 - INFO - No entries found for podcast 32be2efb11ed493ca2c657730068dabb
# 2025-01-29 08:53:04,176 - INFO - No entries found for podcast 53033eac9ce24ad9b5f6ce6929eff4d1
# 2025-01-29 08:53:04,176 - INFO - No entries found for podcast 51be1e23aac2403d953c50b5ee9bc79c
# 2025-01-29 08:53:11,341 - INFO - Processed 12900/117527 feeds
# 2025-01-29 08:53:14,382 - INFO - No entries found for podcast b33030ad4df14d8ebc9550154db47647
# 2025-01-29 08:53:25,557 - INFO - No entries found for podcast e12d533aba2043939a32bffcad3374a5
# 2025-01-29 08:53:28,372 - INFO - No entries found for podcast ea2e4c0bc88f498d92efaaa881f35351
# 2025-01-29 08:53:40,756 - INFO - Processed 13000/117527 feeds
# 2025-01-29 08:53:43,927 - INFO - Processed 13100/117527 feeds
# 2025-01-29 08:53:43,947 - INFO - No entries found for podcast 233bfa0f9b4f49219fd037444dc5d2df
# 2025-01-29 08:53:44,435 - INFO - No entries found for podcast f52ffcaae74942f6bde29f661e6fcea8
# 2025-01-29 08:53:46,791 - INFO - Processed 13200/117527 feeds
# 2025-01-29 08:53:52,293 - INFO - No entries found for podcast 6eee7afd6d96408aa602c63d3e0703a2
# 2025-01-29 08:53:56,443 - INFO - No entries found for podcast 40b3db6f9b3b4d8da5655dea3199771a
# 2025-01-29 08:53:58,289 - INFO - No entries found for podcast 189c469676864a72a8013ab030181147
# 2025-01-29 08:54:00,511 - INFO - No entries found for podcast c4fd284000f64212a6d215fa0858f2c8
# 2025-01-29 08:54:01,446 - INFO - No entries found for podcast d96d127cde8c4e17ab761d276c7ae99e
# 2025-01-29 08:54:05,892 - INFO - No entries found for podcast c0757b2e2ae4436b8ddd389502010df6
# 2025-01-29 08:54:08,565 - INFO - No entries found for podcast b87c7c441c8a416da18c52a2d0c2637f
# 2025-01-29 08:54:09,852 - INFO - No entries found for podcast 2893977ef0ae4456abddca24ae588f39
# 2025-01-29 08:54:10,488 - INFO - Processed 13300/117527 feeds
# 2025-01-29 08:54:10,517 - INFO - Processed 13400/117527 feeds
# 2025-01-29 08:54:11,194 - INFO - No entries found for podcast 69cc3f4b599a4ad087063ac73c8b6041
# 2025-01-29 08:54:34,102 - INFO - No entries found for podcast 2e96d4fe85a54a3aa9c41f604d55d373
# 2025-01-29 08:54:38,603 - INFO - Processed 13500/117527 feeds
# 2025-01-29 08:54:50,913 - INFO - No entries found for podcast a49d32f3f32c4d898fddab1da3b97be6
# 2025-01-29 08:54:52,356 - INFO - No entries found for podcast a9c2ccbad6bf4c2c96907042cbe32b15
# 2025-01-29 08:55:00,085 - INFO - Processed 13600/117527 feeds
# 2025-01-29 08:55:00,904 - INFO - No entries found for podcast 537afb63f09346d281efd3bd978bfaf6
# 2025-01-29 08:55:08,289 - INFO - Processed 13700/117527 feeds
# 2025-01-29 08:55:08,292 - INFO - Processed 13800/117527 feeds
# 2025-01-29 08:55:09,279 - INFO - No entries found for podcast 768a3da315e842d18eb7bbe378f00edb
# 2025-01-29 08:55:09,487 - INFO - No entries found for podcast 931f35cd95764f5e970a630014aca750
# 2025-01-29 08:55:27,176 - INFO - No entries found for podcast a27126b819924e79b5e3eb100c11f736
# 2025-01-29 08:55:27,240 - INFO - No entries found for podcast 773a5175c7e447c799b4aa6fc7d3a234
# 2025-01-29 08:55:28,266 - INFO - No entries found for podcast 444cfeb4780c4cd3ab26944ab6a9d938
# 2025-01-29 08:55:36,527 - INFO - No entries found for podcast d5df79b7cd42483c846d279b3eae40f1
# 2025-01-29 08:55:36,704 - INFO - Processed 13900/117527 feeds
# 2025-01-29 08:55:39,545 - INFO - No entries found for podcast ee6b2e7296bb4165a9f20bda649c50a9
# 2025-01-29 08:55:42,588 - INFO - No entries found for podcast f1044700c18e45c6bcff3632377020e9
# 2025-01-29 08:55:45,644 - INFO - No entries found for podcast 70b760066b0f476f9edc56b3d6e58487
# 2025-01-29 08:55:49,952 - INFO - No entries found for podcast d432cf0e11484c469f0ce122d4c20ab4
# 2025-01-29 08:55:50,007 - INFO - Processed 14000/117527 feeds
# 2025-01-29 08:55:51,740 - INFO - Processed 14100/117527 feeds
# 2025-01-29 08:55:51,756 - INFO - Processed 14200/117527 feeds
# 2025-01-29 08:55:53,200 - INFO - No entries found for podcast 767905b5473e4e8891ad759327cb6e49
# 2025-01-29 08:55:59,690 - INFO - No entries found for podcast b4befd7192584b5eb7585821f2dda044
# 2025-01-29 08:56:04,268 - INFO - No entries found for podcast 5d69dd7afec74d8bba8657340af2f459
# 2025-01-29 08:56:09,469 - INFO - No entries found for podcast 900f11f3ae7746f39009003ec1202f04
# 2025-01-29 08:56:10,772 - INFO - No entries found for podcast c2532636d34e417faee6304d9fda4007
# 2025-01-29 08:56:21,819 - INFO - Processed 14300/117527 feeds
# 2025-01-29 08:56:22,537 - INFO - No entries found for podcast decd068a5ddb44c29f58a82f156b92c9
# 2025-01-29 08:56:25,345 - INFO - No entries found for podcast bcfdaca0bcaf4a4baf73ef3e2a408d11
# 2025-01-29 08:56:33,921 - INFO - Processed 14400/117527 feeds
# 2025-01-29 08:56:34,651 - INFO - No entries found for podcast 1a1ed72d6c7348438073c0ba0693660f
# 2025-01-29 08:56:36,371 - INFO - No entries found for podcast 025c647e91644679ad4a0f56570eba93
# 2025-01-29 08:56:39,771 - INFO - No entries found for podcast 4b3c9bf0e72a4acba9d3e7a308d3a8cb
# 2025-01-29 08:56:41,886 - INFO - No entries found for podcast 196d26bbd54f40cc85d6314e37a3d039
# 2025-01-29 08:56:41,942 - INFO - Processed 14500/117527 feeds
# 2025-01-29 08:56:42,090 - INFO - No entries found for podcast 7f8fef57e1954823aab391792703be1f
# 2025-01-29 08:57:05,090 - INFO - Processed 14600/117527 feeds
# 2025-01-29 08:57:12,660 - INFO - No entries found for podcast b11a956732f846e4ba158686fbcd0c15
# 2025-01-29 08:57:12,663 - INFO - Processed 14700/117527 feeds
# 2025-01-29 08:57:15,370 - INFO - No entries found for podcast 17329b5d83e2446c909f10b1ae3950c7
# 2025-01-29 08:57:26,146 - INFO - Processed 14800/117527 feeds
# 2025-01-29 08:57:32,192 - INFO - No entries found for podcast dce7110c8cb34b5496e2fb105edd418d
# 2025-01-29 08:57:33,031 - INFO - No entries found for podcast 37f7843b1bc848d2a926a7ae55a5fa47
# 2025-01-29 08:57:35,008 - INFO - Processed 14900/117527 feeds
# 2025-01-29 08:57:37,610 - INFO - No entries found for podcast f314221f887c4239930e6bac4310db0a
# 2025-01-29 08:57:39,036 - INFO - No entries found for podcast 4cdde9f049d9475dafcd42c09077bef3
# 2025-01-29 08:57:40,023 - INFO - No entries found for podcast 11244037b7b6427a99f9391a0eb0996e
# 2025-01-29 08:57:40,409 - INFO - No entries found for podcast df48c34a4280447db0940c577d8dd48e
# 2025-01-29 08:57:41,760 - INFO - No entries found for podcast c22adb15814a4b77838482dc741a51c6
# 2025-01-29 08:57:55,980 - INFO - No entries found for podcast 58fb39f011f94c3b87c11ff4debb040c
# 2025-01-29 08:57:56,473 - INFO - Processed 15000/117527 feeds
# 2025-01-29 08:57:56,493 - INFO - Processed 15100/117527 feeds
# 2025-01-29 08:57:58,180 - INFO - No entries found for podcast a71923d1c6364ba4bf1bafcf3c17485d
# 2025-01-29 08:58:01,193 - INFO - No entries found for podcast b3a593f8662f46f59839eb8dc06677aa
# 2025-01-29 08:58:03,760 - INFO - No entries found for podcast 9908b587a52f4223a654f8d76f1cbc27
# 2025-01-29 08:58:04,079 - INFO - No entries found for podcast ebfc5d45197349618f0eb51f58567ddb
# 2025-01-29 08:58:14,391 - INFO - Processed 15200/117527 feeds
# 2025-01-29 08:58:20,337 - INFO - No entries found for podcast 5da2681b5d314cd6ad19b407d62a86fe
# 2025-01-29 08:58:33,230 - INFO - Processed 15300/117527 feeds
# 2025-01-29 08:58:45,592 - INFO - Processed 15400/117527 feeds
# 2025-01-29 08:58:47,650 - INFO - Processed 15500/117527 feeds
# 2025-01-29 08:58:50,030 - INFO - No entries found for podcast ed964827f5e24f2db25fba008d38713b
# 2025-01-29 08:58:56,749 - INFO - No entries found for podcast ed579757a75d4b668e91f9530fae2b31
# 2025-01-29 08:58:59,815 - INFO - No entries found for podcast 925e396132c14af797e8209adb658301
# 2025-01-29 08:59:07,532 - INFO - Processed 15600/117527 feeds
# 2025-01-29 08:59:10,112 - INFO - No entries found for podcast b376714b255e43a5b8b13b0e0ec7cf9d
# 2025-01-29 08:59:11,610 - INFO - No entries found for podcast 10973563ed8c417a8b1e9ba439039453
# 2025-01-29 08:59:15,166 - INFO - No entries found for podcast 5b7440a0141e4532939be0f5f2ed4639
# 2025-01-29 08:59:18,685 - INFO - No entries found for podcast 5926aef14d7d44a59969170d9c24541e
# 2025-01-29 08:59:20,063 - INFO - No entries found for podcast a56dd450504f49e6b8ad49a38298f7e2
# 2025-01-29 08:59:28,277 - INFO - No entries found for podcast 5040ed09ad1b4c27b312570ebfb2bc73
# 2025-01-29 08:59:33,399 - INFO - Processed 15700/117527 feeds
# 2025-01-29 08:59:45,231 - INFO - No entries found for podcast 6114cb74ba7847a1af310044ee4379fa
# 2025-01-29 08:59:49,467 - INFO - Processed 15800/117527 feeds
# 2025-01-29 08:59:52,690 - INFO - Processed 15900/117527 feeds
# 2025-01-29 08:59:52,693 - INFO - Processed 16000/117527 feeds
# 2025-01-29 08:59:58,394 - INFO - No entries found for podcast 6c235748941e4bb090afa2ecbe305552
# 2025-01-29 09:00:00,952 - INFO - No entries found for podcast 51b2090ca8ff4240a6cd96d8f5296a95
# 2025-01-29 09:00:11,356 - INFO - No entries found for podcast b7f66bcaab044c5482ef5b24c0df321a
# 2025-01-29 09:00:17,904 - INFO - Processed 16100/117527 feeds
# 2025-01-29 09:00:17,983 - INFO - No entries found for podcast 03829fffda7b4699a6d0a2abf817447b
# 2025-01-29 09:00:21,747 - INFO - No entries found for podcast 3c5430d8718041fe9bae37f3df3e1a25
# 2025-01-29 09:00:33,073 - INFO - No entries found for podcast 9d7726a5ee1740a8a715b0b9f6c8eb83
# 2025-01-29 09:00:37,075 - INFO - Processed 16200/117527 feeds
# 2025-01-29 09:00:38,001 - INFO - No entries found for podcast ee5f13d7c0ee4a31a15f7c06bddded23
# 2025-01-29 09:00:38,478 - INFO - No entries found for podcast d5207569866f4d84a145eaabcc19ba97
# 2025-01-29 09:00:45,692 - INFO - No entries found for podcast f31d11b17fcd48c194a818ecba2d6777
# 2025-01-29 09:00:49,779 - INFO - Processed 16300/117527 feeds
# 2025-01-29 09:00:58,153 - INFO - No entries found for podcast 7c90e6279cfb43628d018c86a8ad5df2
# ...
# 2025-01-29 13:02:25,276 - INFO - Processed 112500/117527 feeds
# 2025-01-29 13:02:26,318 - INFO - Processed 112600/117527 feeds
# 2025-01-29 13:02:34,729 - INFO - No entries found for podcast 6187f327ac004ae3ba6301923b696da8
# 2025-01-29 13:02:35,337 - INFO - No entries found for podcast 8d1e37a651484e129ba6ac2dfee85607
# 2025-01-29 13:02:38,166 - INFO - No entries found for podcast 7f9fdc0800414f099c2d1b5c01fc0e10
# 2025-01-29 13:02:38,697 - INFO - No entries found for podcast a89fdb4d26734390adaa249c9a522a89
# 2025-01-29 13:02:39,805 - INFO - No entries found for podcast d047703ce33c4ba99ee1d34a8bf2e064
# 2025-01-29 13:02:40,825 - INFO - No entries found for podcast 0fbf29cb8166421d8fa77b481ca954ea
# 2025-01-29 13:02:43,686 - INFO - No entries found for podcast 2955c6de582641509a2d3cea17d39593
# 2025-01-29 13:02:48,193 - INFO - No entries found for podcast 352fb176c9be40389cf30286286eb02d
# 2025-01-29 13:02:49,937 - INFO - Processed 112700/117527 feeds
# 2025-01-29 13:02:50,452 - INFO - No entries found for podcast 2da958ab8d7049b783262f9fbe314871
# 2025-01-29 13:02:51,285 - INFO - No entries found for podcast 9f84106c475343b9ad4c60f18d0701dc
# 2025-01-29 13:03:02,388 - INFO - Processed 112800/117527 feeds
# 2025-01-29 13:03:07,805 - INFO - No entries found for podcast 4d72ebd179154922a6a940c0e4b4b1a2
# 2025-01-29 13:03:10,177 - INFO - Processed 112900/117527 feeds
# 2025-01-29 13:03:10,328 - INFO - No entries found for podcast 5276ee74e5e14ef084626628b6e13b98
# 2025-01-29 13:03:14,272 - INFO - No entries found for podcast 40e3bfb974f24c65859f4d96eb7bb9ab
# 2025-01-29 13:03:14,290 - INFO - No entries found for podcast b28beb79f29446d697b5aef48d6aadcd
# 2025-01-29 13:03:14,772 - INFO - No entries found for podcast 0b6d71a7033d47af889ce11bab69236c
# 2025-01-29 13:03:28,541 - INFO - No entries found for podcast 376771a30c4c49c58328ccabc2c64298
# 2025-01-29 13:03:33,033 - INFO - Processed 113000/117527 feeds
# 2025-01-29 13:03:52,754 - INFO - No entries found for podcast 00c374c2466447a390f5ac14558e660f
# 2025-01-29 13:03:52,757 - INFO - Processed 113100/117527 feeds
# 2025-01-29 13:03:59,024 - INFO - No entries found for podcast 2ffb69b9141342e9a7bb9143ab572116
# 2025-01-29 13:03:59,042 - INFO - No entries found for podcast 772f2cff085e487183ad6fa8749d9d07
# 2025-01-29 13:04:02,578 - INFO - No entries found for podcast 22ed4eeec7904cd78c35f69571ccf097
# 2025-01-29 13:04:09,278 - INFO - No entries found for podcast 4677f710c4a24dcd9d34ac8bfb05372f
# 2025-01-29 13:04:16,404 - INFO - No entries found for podcast 9818b849d1b4473f8c29226f8cc5c530
# 2025-01-29 13:04:21,208 - INFO - Processed 113200/117527 feeds
# 2025-01-29 13:04:26,880 - INFO - Processed 113300/117527 feeds
# 2025-01-29 13:04:28,319 - INFO - No entries found for podcast 005c36030b76450297fc1635be9039e7
# 2025-01-29 13:04:34,245 - INFO - No entries found for podcast eac255266b554827bc7966d9c4dec79c
# 2025-01-29 13:04:41,684 - INFO - No entries found for podcast 55be26c551f041b89e5f6d00f079e939
# 2025-01-29 13:04:43,769 - INFO - No entries found for podcast 84c50226d1a04f7ca60313ce96e84bd7
# 2025-01-29 13:04:44,752 - INFO - No entries found for podcast 8571f4c7d43b44afb453cd15a5ea997a
# 2025-01-29 13:04:47,650 - INFO - No entries found for podcast 04c46e81de9745249a6fe4f7b2c1df08
# 2025-01-29 13:04:47,668 - INFO - No entries found for podcast b7d729a98a2a4c05908ba3de648e6cad
# 2025-01-29 13:04:52,428 - INFO - No entries found for podcast b4a377abc27e461e9ee2704187c1eee6
# 2025-01-29 13:04:52,753 - INFO - Processed 113400/117527 feeds
# 2025-01-29 13:04:56,472 - INFO - No entries found for podcast 86f757e284e44b6a8cdace70f7143889
# 2025-01-29 13:05:03,227 - INFO - No entries found for podcast 6ab614ba02444befa41b70876fc6ae2b
# 2025-01-29 13:05:04,364 - INFO - Processed 113500/117527 feeds
# 2025-01-29 13:05:05,992 - INFO - No entries found for podcast 6160e0090ae34e09879a3dc36824b884
# 2025-01-29 13:05:17,712 - INFO - Processed 113600/117527 feeds
# 2025-01-29 13:05:17,749 - INFO - Processed 113700/117527 feeds
# 2025-01-29 13:05:21,329 - INFO - No entries found for podcast d7b6acc60dff43b0b4914560dd916638
# 2025-01-29 13:05:29,352 - INFO - No entries found for podcast b31acec54f4c4a3ea3496ec559534c28
# 2025-01-29 13:05:39,805 - INFO - No entries found for podcast 90d273081b9e491494121f46581f98e6
# 2025-01-29 13:05:54,523 - INFO - No entries found for podcast cefad156f15f4e1b80f7cee77a2acbe7
# 2025-01-29 13:05:56,234 - INFO - No entries found for podcast b8f6ae90a83f42b194fce8646e64660d
# 2025-01-29 13:05:57,117 - INFO - Processed 113800/117527 feeds
# 2025-01-29 13:05:57,515 - INFO - No entries found for podcast 9aa8a943adcc4970b73a800796203a7b
# 2025-01-29 13:05:58,323 - INFO - No entries found for podcast 690db78bafa444998bcadfee265ac40b
# 2025-01-29 13:05:58,377 - INFO - No entries found for podcast 67253f7731d54a6ab069a8f66a4b8075
# 2025-01-29 13:05:59,199 - INFO - No entries found for podcast bd025bb5692e449298932c1559409aee
# 2025-01-29 13:05:59,221 - INFO - No entries found for podcast fb3b12b7a1e84c3d81a05d9d2aff758a
# 2025-01-29 13:06:00,000 - INFO - Processed 113900/117527 feeds
# 2025-01-29 13:06:03,688 - INFO - No entries found for podcast 98fe68191bf94c16b8282245b0ef98ea
# 2025-01-29 13:06:05,581 - INFO - No entries found for podcast 212e078ea28b453fb3fafb4954f59e36
# 2025-01-29 13:06:25,709 - INFO - No entries found for podcast 008401326a274b779100855ad63034ca
# 2025-01-29 13:06:28,854 - INFO - No entries found for podcast 984be8bbb2114ec6a66a7f1b83817f79
# 2025-01-29 13:06:31,219 - INFO - No entries found for podcast ab8af4639bc2480e87ddc047aa630019
# 2025-01-29 13:06:41,922 - INFO - No entries found for podcast e59e2cdac0be4f41a6816effb96840a0
# 2025-01-29 13:06:43,708 - INFO - No entries found for podcast 11c075eaaaf148a1ab1c8899638d0d30
# 2025-01-29 13:06:43,710 - INFO - Processed 114000/117527 feeds
# 2025-01-29 13:06:43,726 - INFO - Processed 114100/117527 feeds
# 2025-01-29 13:06:46,581 - INFO - No entries found for podcast 1119566aaa1243ee96e911d298266374
# 2025-01-29 13:06:54,347 - INFO - Processed 114200/117527 feeds
# 2025-01-29 13:06:58,290 - INFO - No entries found for podcast 99aea6edf3324113b5f68367914fc7ff
# 2025-01-29 13:06:58,718 - INFO - No entries found for podcast 5205a168010b4922b812573911d85252
# 2025-01-29 13:07:07,308 - INFO - No entries found for podcast f2e69bd2ebc343549986d65fe387ad00
# 2025-01-29 13:07:07,327 - INFO - No entries found for podcast 478d2ebfc3984f2ba78b802ff2a0e9ac
# 2025-01-29 13:07:13,792 - INFO - No entries found for podcast 5a5067b9bb474ef897dbc29da15425ff
# 2025-01-29 13:07:18,374 - INFO - No entries found for podcast 62b44382c50e4f6eab203067c0ee8bb6
# 2025-01-29 13:07:19,562 - INFO - No entries found for podcast 79d3630c6fc64faca81e3e48ac0a189a
# 2025-01-29 13:07:20,706 - INFO - No entries found for podcast 072b3e99dbad460097c52eb22cdc0061
# 2025-01-29 13:07:22,881 - INFO - Processed 114300/117527 feeds
# 2025-01-29 13:07:22,883 - INFO - Processed 114400/117527 feeds
# 2025-01-29 13:07:22,890 - INFO - No entries found for podcast a61cc05ed1b845248207a662e968fe7d
# 2025-01-29 13:07:22,891 - INFO - Processed 114500/117527 feeds
# 2025-01-29 13:07:24,891 - INFO - No entries found for podcast eaa06a458c8a482393d7cc26f5bee266
# 2025-01-29 13:07:44,731 - INFO - No entries found for podcast 271510bcf1a54186961f537610d9674d
# 2025-01-29 13:07:46,398 - INFO - No entries found for podcast 163569a910bd474fb5df3fc89a8f9d95
# 2025-01-29 13:07:50,062 - INFO - No entries found for podcast 16cc5c39fb654f559f65efc43433ee00
# 2025-01-29 13:07:51,481 - INFO - No entries found for podcast 0d7ba025a4094ee9ac45bbd6872e2466
# 2025-01-29 13:07:51,852 - INFO - No entries found for podcast 5c16e0e578de48aea8a576e9d61dd7ce
# 2025-01-29 13:07:53,683 - INFO - No entries found for podcast 2385abbcda0948748143191e54343eae
# 2025-01-29 13:07:57,331 - INFO - Processed 114600/117527 feeds
# 2025-01-29 13:08:00,684 - INFO - No entries found for podcast 831ccf2454404d009601c7f4cea2b3e0
# 2025-01-29 13:08:00,723 - INFO - No entries found for podcast 1676be2040b74024b90c0580b0ba3abe
# 2025-01-29 13:08:00,905 - INFO - No entries found for podcast 60e12e3cb2ec48818192176258486e62
# 2025-01-29 13:08:10,092 - INFO - No entries found for podcast ad7da212c947425683a16b0aabef4658
# 2025-01-29 13:08:14,952 - ERROR - Error processing feed 349f67dc76f44325838e5fa1723a193c: Remote end closed connection without response
# 2025-01-29 13:08:41,646 - INFO - No entries found for podcast 91c0280d79474cfaad46ba8d2d09e044
# 2025-01-29 13:08:56,992 - INFO - No entries found for podcast 9e2cd7a6e10f46bcb0d1d6e9eff10542
# 2025-01-29 13:09:03,659 - INFO - No entries found for podcast 2efd788041894116b97030cfcb24f9b3
# 2025-01-29 13:09:03,920 - ERROR - Error processing feed d6db94f9d43b4d00a66629c56c02c964: Remote end closed connection without response
# 2025-01-29 13:09:03,965 - INFO - No entries found for podcast 9d27dc8b46194d35856dd2826fd66171
# 2025-01-29 13:09:04,183 - INFO - No entries found for podcast 9f75b5b05088420892ef64ba85a62c4b
# 2025-01-29 13:09:04,757 - INFO - No entries found for podcast 3931bb739f354dffacba64ad85c6a553
# 2025-01-29 13:09:06,526 - INFO - No entries found for podcast 58792d4e4988483d96d34d38c3fb1935
# 2025-01-29 13:09:10,315 - INFO - No entries found for podcast e13dab0f2ec040c28cab74b9fcbc6fb0
# 2025-01-29 13:09:14,683 - INFO - No entries found for podcast f4e997b56aaa49cf97fc3a8de0988d13
# 2025-01-29 13:09:24,248 - INFO - No entries found for podcast cb804a426140401db2521522133fa4aa
# 2025-01-29 13:09:38,996 - INFO - No entries found for podcast d13fc2c98f584db3bcea0a8ae90fc056
# 2025-01-29 13:09:58,885 - INFO - No entries found for podcast f61bc16fe9c7473c973eb4e1ead84232
# 2025-01-29 13:09:59,188 - INFO - No entries found for podcast 0a8a34b483e943ce9f0a5cb3a29ac798
# 2025-01-29 13:10:00,897 - INFO - No entries found for podcast f0ef2c352e20452e8999eec3a86d1502
# 2025-01-29 13:10:03,343 - INFO - No entries found for podcast d161c013f486411b801c39de36424d3e
# 2025-01-29 13:10:06,863 - INFO - No entries found for podcast ae4feebbbd874992af0202beec6321ec
# 2025-01-29 13:10:13,722 - INFO - No entries found for podcast 8ee977c623714599a124f4f8061dbcbe
# 2025-01-29 13:10:19,933 - INFO - No entries found for podcast dd1b2a2ad5fd425d924bf81824fa6249
# 2025-01-29 13:10:27,715 - INFO - No entries found for podcast a6ece57cf3954d4c9b816f05c3fc40de
# 2025-01-29 13:10:27,828 - INFO - Processed 114700/117527 feeds
# 2025-01-29 13:10:27,838 - INFO - Processed 114800/117527 feeds
# 2025-01-29 13:10:27,839 - INFO - Processed 114900/117527 feeds
# 2025-01-29 13:10:27,840 - INFO - Processed 115000/117527 feeds
# 2025-01-29 13:10:27,840 - INFO - Processed 115100/117527 feeds
# 2025-01-29 13:10:27,855 - INFO - Processed 115200/117527 feeds
# 2025-01-29 13:10:28,190 - INFO - Processed 115300/117527 feeds
# 2025-01-29 13:10:28,191 - INFO - Processed 115400/117527 feeds
# 2025-01-29 13:10:28,615 - INFO - No entries found for podcast 96dfdeaa3f894a9a995c04c594341fa5
# 2025-01-29 13:10:34,855 - INFO - No entries found for podcast f05789dc36954bafbffecab98fb6a739
# 2025-01-29 13:10:45,185 - INFO - No entries found for podcast 4e4433b41aed4b1695e718606017bb77
# 2025-01-29 13:10:54,865 - INFO - No entries found for podcast e32feb722e034875943955940a3ed8d3
# 2025-01-29 13:10:55,191 - INFO - No entries found for podcast b7c0a2084e894e6fb8a56223630d209e
# 2025-01-29 13:11:08,795 - INFO - No entries found for podcast 0071e0a31168442c949d2b436f6e21db
# 2025-01-29 13:11:09,635 - INFO - No entries found for podcast 25713ea005ba4c11b047104b97ea4f50
# 2025-01-29 13:11:12,368 - INFO - No entries found for podcast c89b439d8d334198a7b4b578c1f21742
# 2025-01-29 13:11:25,330 - INFO - No entries found for podcast a687c08f903842118e94431a6892863e
# 2025-01-29 13:11:31,754 - INFO - No entries found for podcast 12209c48d9104d3080ac62c4d037a41b
# 2025-01-29 13:11:33,644 - INFO - No entries found for podcast ebffb5e41e8c4a8f9fe7f3d47768086f
# 2025-01-29 13:11:38,365 - INFO - No entries found for podcast b19286b8bc0145a2a9bbfb62a34245b5
# 2025-01-29 13:11:39,902 - INFO - No entries found for podcast 2dbf9085eda04ab386e89de1081b21f8
# 2025-01-29 13:11:39,960 - INFO - No entries found for podcast 1f9af18c940c40dfb3d6bba96b3ed42d
# 2025-01-29 13:11:49,827 - INFO - No entries found for podcast 56b323abb0dd48ae8ed6d608e2a43d70
# 2025-01-29 13:11:52,488 - INFO - No entries found for podcast 4bac0355885f48de988e39b68008f2a6
# 2025-01-29 13:11:58,981 - INFO - No entries found for podcast cbb5ad4679784179add84184d830eaeb
# 2025-01-29 13:12:10,936 - INFO - No entries found for podcast 6fe77ccf89ca41d8976ddeab1bc79a33
# 2025-01-29 13:12:27,070 - INFO - No entries found for podcast 5244db51a4484871be0bf4ff6effef8b
# 2025-01-29 13:12:31,521 - INFO - No entries found for podcast 14912817aefd443bba4538851531584b
# 2025-01-29 13:12:40,783 - INFO - No entries found for podcast 816b9e3a223d4c13975ddf07bd4b4145
# 2025-01-29 13:12:44,684 - INFO - No entries found for podcast 0397048f59364bdf8329817134ab4e26
# 2025-01-29 13:12:51,200 - INFO - No entries found for podcast 060b2627789f49a6b2130ed3ec96be3f
# 2025-01-29 13:13:17,970 - INFO - No entries found for podcast e88e27d7961e4f2594123ab6b21ec978
# 2025-01-29 13:13:18,846 - INFO - No entries found for podcast a3727e41a02b4044a8e76dbe78dd89ca
# 2025-01-29 13:13:19,365 - INFO - No entries found for podcast d5b42e9e44164837ab38174390f149df
# 2025-01-29 13:13:22,832 - INFO - No entries found for podcast 0b3858563c204573a861b2a298082866
# 2025-01-29 13:13:28,673 - INFO - No entries found for podcast 89929464b7c94027af809a96ec63b8c1
# 2025-01-29 13:13:40,691 - INFO - No entries found for podcast dfed572fa81c48bf9e77401a129f3d6d
# 2025-01-29 13:13:50,353 - INFO - No entries found for podcast 2aa48e10f4bd40cd9b365e1f00153af5
# 2025-01-29 13:13:50,871 - INFO - No entries found for podcast 4a09dfddcb9545f9abf0ca6b21fd1f35
# 2025-01-29 13:13:53,085 - INFO - No entries found for podcast 772e7f26614d4beca753b9d34f10495f
# 2025-01-29 13:14:03,354 - INFO - No entries found for podcast a08c3903bd8a434697ec82d11c3e9ce0
# 2025-01-29 13:14:06,283 - INFO - No entries found for podcast f1e75218c9c3481abfbf9d7e31e80098
# 2025-01-29 13:14:12,706 - INFO - No entries found for podcast 279886c3b2484bdd82652f03a962d22c
# 2025-01-29 13:14:19,632 - INFO - No entries found for podcast 09568bae75d44790811672d0b34207d0
# 2025-01-29 13:14:21,583 - INFO - No entries found for podcast cd523797b2934afcbcc39d095d3d88f2
# 2025-01-29 13:14:57,323 - INFO - No entries found for podcast 8f07bce666d74915b54153b884df3a6f
# 2025-01-29 13:14:58,902 - INFO - No entries found for podcast 467d9f66fd2649f3b0b9a8ba45a4ee4a
# 2025-01-29 13:15:28,211 - ERROR - Feed processing failed:
# 2025-01-29 13:15:28,212 - INFO - Processed 115500/117527 feeds
# 2025-01-29 13:15:28,212 - INFO - Processed 115600/117527 feeds
# 2025-01-29 13:15:28,213 - INFO - Processed 115700/117527 feeds
# 2025-01-29 13:15:28,213 - INFO - Processed 115800/117527 feeds
# 2025-01-29 13:15:28,213 - INFO - Processed 115900/117527 feeds
# 2025-01-29 13:15:28,214 - INFO - Processed 116000/117527 feeds
# 2025-01-29 13:15:28,214 - INFO - Processed 116100/117527 feeds
# 2025-01-29 13:15:28,215 - INFO - Processed 116200/117527 feeds
# 2025-01-29 13:15:28,215 - INFO - Processed 116300/117527 feeds
# 2025-01-29 13:15:28,215 - INFO - Processed 116400/117527 feeds
# 2025-01-29 13:15:28,215 - INFO - Processed 116500/117527 feeds
# 2025-01-29 13:15:28,216 - INFO - Processed 116600/117527 feeds
# 2025-01-29 13:15:28,216 - INFO - Processed 116700/117527 feeds
# 2025-01-29 13:15:28,217 - INFO - Processed 116800/117527 feeds
# 2025-01-29 13:15:28,218 - INFO - Processed 116900/117527 feeds
# 2025-01-29 13:15:28,218 - INFO - Processed 117000/117527 feeds
# 2025-01-29 13:15:28,219 - INFO - Processed 117100/117527 feeds
# 2025-01-29 13:15:28,219 - INFO - Processed 117200/117527 feeds
# 2025-01-29 13:15:28,219 - INFO - Processed 117300/117527 feeds
# 2025-01-29 13:15:28,220 - INFO - Processed 117400/117527 feeds
# 2025-01-29 13:15:28,220 - INFO - Processed 117500/117527 feeds
# 2025-01-29 13:15:57,830 - ERROR - Error processing feed e8cb0cbc30eb41ea8d0418d3de60a518: IncompleteRead(65299 bytes read, 417133 more expected)

# %%
import os
import re
import pandas as pd
from sqlalchemy import create_engine, text
import logging
from sqlalchemy.exc import IntegrityError

# Configure logging
logging.basicConfig(
    level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s'
)

# Database credentials
db_user = os.getenv('DB_USER', 'jcervantez')
db_password = os.getenv('DB_PASSWORD', 'Cervantez12')
db_host = os.getenv('DB_HOST', 'localhost')
db_port = os.getenv('DB_PORT', '5432')
db_name = os.getenv('DB_NAME', 'podcast_episodes')

# Create the PostgreSQL database engine
engine = create_engine(
    f'postgresql+psycopg2://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}',
)

# Define chunksize based on your system's capacity
chunksize = 100000  # Adjust as needed

def clean_date_string(date_str):
    if pd.isnull(date_str):
        return date_str
    if isinstance(date_str, str):
        # Remove unrecognized time zone abbreviations
        cleaned_str = re.sub(r'\b[A-Z]{3,5}$', '', date_str.strip())
        return cleaned_str.strip()
    else:
        # If it's already a Timestamp or datetime object, return it as is
        return date_str

def process_chunk(chunk):
    # Clean the date strings
    chunk['episode_published_cleaned'] = chunk['episode_published'].apply(clean_date_string)

    # Parse dates using pd.to_datetime with utc=True
    chunk['episode_published_parsed'] = pd.to_datetime(
        chunk['episode_published_cleaned'], errors='coerce', utc=True
    )
    
    # Drop rows where date parsing failed
    chunk = chunk.dropna(subset=['episode_published_parsed'])

    # Check if chunk is empty after dropping rows with unparseable dates
    if chunk.empty:
        return pd.DataFrame()

    # Filter episodes from 2024 and 2025
    filtered_chunk = chunk[
        (chunk['episode_published_parsed'].dt.year >= 2024) &
        (chunk['episode_published_parsed'].dt.year <= 2025)
    ]

    # Check if chunk is empty after date filtering
    if filtered_chunk.empty:
        return pd.DataFrame()

    # Remove episodes with empty descriptions
    filtered_chunk = filtered_chunk[
        filtered_chunk['episode_description'].notna() &  # Not null
        (filtered_chunk['episode_description'].str.strip() != '')  # Not empty or whitespace
    ]

    # Check if chunk is empty after filtering descriptions
    if filtered_chunk.empty:
        return pd.DataFrame()

    # Drop the temporary date columns
    filtered_chunk = filtered_chunk.drop(
        columns=['episode_published_cleaned', 'episode_published_parsed']
    )

    # Remove duplicates within the chunk
    filtered_chunk = filtered_chunk.drop_duplicates(subset=['podcast_id', 'episode_id'])

    return filtered_chunk

try:
    # Enable autocommit mode
    with engine.connect().execution_options(isolation_level="AUTOCOMMIT") as conn:
        # Drop the existing episodes_recent table to start fresh
        conn.execute(text("DROP TABLE IF EXISTS episodes_recent;"))
        logging.info("Dropped existing episodes_recent table.")

        # Create episodes_recent table with the same schema as episodes
        conn.execute(text("""
        CREATE TABLE episodes_recent AS TABLE episodes WITH NO DATA;
        """))
        logging.info("Created new episodes_recent table.")

        # Add unique constraint to episodes_recent table
        conn.execute(text("""
        ALTER TABLE episodes_recent
        ADD CONSTRAINT unique_podcast_episode UNIQUE (podcast_id, episode_id);
        """))
        logging.info("Added unique constraint to episodes_recent table.")

    # Use a generator to read data in chunks
    for chunk in pd.read_sql_table('episodes', engine, chunksize=chunksize):
        try:
            filtered_chunk = process_chunk(chunk)
            if not filtered_chunk.empty:
                # Insert data into episodes_recent
                filtered_chunk.to_sql(
                    'episodes_recent', engine, if_exists='append', index=False, method='multi'
                )
        except Exception as e:
            logging.error(f"Error processing a chunk: {e}")
except Exception as e:
    logging.error(f"Error in processing: {e}")
    exit(1)

# After processing all chunks, delete episodes from podcasts with fewer than 10 episodes
try:
    with engine.connect().execution_options(isolation_level="AUTOCOMMIT") as conn:
        # Delete episodes from podcasts with fewer than 10 episodes in episodes_recent
        delete_query = text("""
        DELETE FROM episodes_recent er
        USING (
            SELECT podcast_id
            FROM episodes_recent
            GROUP BY podcast_id
            HAVING COUNT(*) < 10
        ) pc
        WHERE er.podcast_id = pc.podcast_id;
        """)
        conn.execute(delete_query)
        logging.info("Deleted episodes from podcasts with fewer than 10 episodes.")
except Exception as e:
    logging.error(f"Error deleting episodes: {e}")
    exit(1)

# Get the total number of unique podcasts in episodes_recent
try:
    with engine.connect() as conn:
        result = conn.execute(text("""
        SELECT COUNT(DISTINCT podcast_id) FROM episodes_recent;
        """))
        unique_podcast_count = result.scalar()
        logging.info(
            f"Total number of unique podcasts in episodes_recent: {unique_podcast_count}"
        )
        print(f"Total number of unique podcasts in episodes_recent: {unique_podcast_count}")
except Exception as e:
    logging.error(f"Error retrieving unique podcast count: {e}")
    exit(1)

logging.info("episodes_recent table created successfully.")
# Out:
# 2025-01-29 14:04:01,223 - INFO - Dropped existing episodes_recent table.
# 2025-01-29 14:04:01,231 - INFO - Created new episodes_recent table.
# 2025-01-29 14:04:01,234 - INFO - Added unique constraint to episodes_recent table.
# 2025-01-29 14:15:22,568 - INFO - Deleted episodes from podcasts with fewer than 10 episodes.
# 2025-01-29 14:15:30,585 - INFO - Total number of unique podcasts in episodes_recent: 76552
# 2025-01-29 14:15:30,587 - INFO - episodes_recent table created successfully.
# Total number of unique podcasts in episodes_recent: 76552

# %%
import os
import subprocess
import gzip
from datetime import datetime
import getpass
import shlex

# Database credentials
db_user = os.getenv('DB_USER', 'jcervantez')
db_password = os.getenv('DB_PASSWORD', 'Cervantez12')
db_host = os.getenv('DB_HOST', 'localhost')
db_port = os.getenv('DB_PORT', '5432')
db_name = os.getenv('DB_NAME', 'podcast_episodes')

# Path to pg_dump executable
pg_dump_path = r'C:\Program Files\PostgreSQL\17\bin\pg_dump.exe'

# Output file name with timestamp
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
output_sql_file = f'episodes_{timestamp}.sql'
compressed_file = f'{output_sql_file}.gz'

# Construct the pg_dump command
pg_dump_cmd = [
    pg_dump_path,
    '-h', db_host,
    '-p', db_port,
    '-U', db_user,
    '-t', 'podcasts_even',  # Specify the table
    '-F', 'p',  # Plain SQL format
    '--no-owner',
    '--no-privileges',
    db_name,
]

# Since the path may contain spaces, we need to use shell=True, but this poses security risks.
# Alternatively, we can use shlex.quote to handle paths with spaces securely.

# Environment variable for PostgreSQL password
env = os.environ.copy()
env['PGPASSWORD'] = db_password

try:
    # Run pg_dump and capture the output
    with open(output_sql_file, 'wb') as out_sql_file:
        subprocess.run(pg_dump_cmd, env=env, stdout=out_sql_file, check=True)
    print(f"Successfully exported {output_sql_file}")

    # Compress the SQL file using gzip
    with open(output_sql_file, 'rb') as f_in, gzip.open(compressed_file, 'wb') as f_out:
        f_out.writelines(f_in)
    print(f"Successfully compressed to {compressed_file}")

    # Optionally, remove the uncompressed SQL file
    os.remove(output_sql_file)
    print(f"Removed uncompressed SQL file {output_sql_file}")

except subprocess.CalledProcessError as e:
    print(f"An error occurred while running pg_dump: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Successfully exported episodes_20250131_065139.sql
# Successfully compressed to episodes_20250131_065139.sql.gz
# Removed uncompressed SQL file episodes_20250131_065139.sql

# %%
#!/usr/bin/env python3
"""
Script to debug podcast_episodes.sql for problematic encoding issues in descriptions.

This script will:
1. Open the podcast_episodes.sql file in binary mode.
2. Search for occurrences of problematic byte sequences (e.g., 0x8F)
   that might indicate problematic text in the description.
3. Print out the count and context (a snippet around the occurrence) for each.
"""

import re

def debug_sql_file(file_path):
    problematic_bytes = {
        b'\x8f': "0x8F",
        # Add other byte sequences if you suspect additional ones
    }
    
    try:
        with open(file_path, "rb") as f:
            data = f.read()
    except Exception as e:
        print(f"Error reading file {file_path}: {e}")
        return

    for byte_seq, desc in problematic_bytes.items():
        matches = [m.start() for m in re.finditer(re.escape(byte_seq), data)]
        print(f"Found {len(matches)} occurrences of byte {desc}.")
        for pos in matches:
            # extract 20 bytes of context before and after the occurrence
            start = max(0, pos - 20)
            end = pos + 20
            snippet = data[start:end]
            try:
                snippet_decoded = snippet.decode("utf-8")
            except Exception as e:
                snippet_decoded = snippet.decode("utf-8", errors="replace")
            print(f"At position {pos}: ...{snippet_decoded}...")

if __name__ == "__main__":
    sql_file = "podcast_episodes_20250220_085140.sql"
    print(f"Scanning {sql_file} for problematic byte sequences...\n")
    debug_sql_file(sql_file)
    print("\nDone scanning!")
# Out:
# Scanning podcast_episodes_20250220_085140.sql for problematic byte sequences...
#
# Found 0 occurrences of byte 0x8F.
#
# Done scanning!
